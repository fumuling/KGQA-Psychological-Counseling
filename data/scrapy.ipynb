# %%
import requests
import json
from lxml import etree
from selenium import webdriver

# %%
url = 'http://jibing.wenyw.com/keshi-88.shtml'
url2 = 'http://jibing.wenyw.com/keshi-88/2.shtml'
options = webdriver.ChromeOptions()
options.add_argument('lang=zh_CN.UTF-8')
driver = webdriver.Chrome(chrome_options=options, executable_path='./chromedriver.exe')
# Out:
# <ipython-input-3-393a75134114>:5: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=options, executable_path='./chromedriver.exe')

# %%
driver.get(url=url)
page = driver.page_source
page_html = etree.HTML(page)
disease_name_list = page_html.xpath('/html/body/div[3]/div[1]/ul[2]/div/ul[2]/li/a/text()')
disease_urlpostfix_list = page_html.xpath('/html/body/div[3]/div[1]/ul[2]/div/ul[2]/li/a/@href')

# %%
dic = {}
for i in range(len(disease_name_list)):
    dic[disease_name_list[i]] = disease_urlpostfix_list[i]
dic
# Out:
# {'早恋': '/zaolian/',
#  '产后抑郁症': '/chanhouyiyuzheng/',
#  '癔症': '/zuozheng/',
#  '幻觉': '/huanjue/',
#  '意志缺乏症': '/yizhiquefazheng/',
#  '口吃': '/kouchi/',
#  '露阴症': '/luyinzheng/',
#  '强迫性障碍': '/qiangpoxingzhangai/',
#  '轻度抑郁发作': '/qingduyiyufazuo/',
#  '人格障碍': '/rengezhangai/',
#  '神经性厌食': '/shenjingxingyanshi/',
#  '神经衰弱': '/shenjingshuairuo/',
#  '社交恐惧症': '/shejiaokongjuzheng/',
#  '神经质': '/shenjingzhi/',
#  '贪食': '/tanshi/',
#  '性交疼痛': '/xingjiaotengtong/',
#  '抑郁症': '/yiyuzheng/',
#  '疑病症': '/yibingzheng/',
#  '厌食症 ': '/yanshizheng /',
#  '强迫症': '/qiangpozheng/',
#  '歇斯底里': '/xiesidili/',
#  '忧郁症': '/youyuzheng/',
#  '心理障碍': '/xinlizhangai/',
#  '重度抑郁症': '/zhongduyiyuzheng/',
#  '躁郁症': '/zaoyuzheng/',
#  '自闭症': '/zibizheng/',
#  '纤维肌痛综合症': '/xianweijitongzonghezheng/',
#  '恋物癖': '/lianwuzuo/',
#  '创伤后应激障碍': '/chuangshanghouyingjizhangai/',
#  '癫狂病': '/zuokuangbing/',
#  '儿童精神分裂症': '/ertongjingshenfenliezheng/',
#  '忽略症': '/huluezheng/',
#  '非器质性阴道痉挛': '/feiqizhixingyindaojingluan/',
#  '睡眠障碍': '/shuimianzhangai/',
#  '遗尿症': '/yiniaozheng/',
#  '恐怖性焦虑障碍': '/kongbuxingjiaolvzhangai/',
#  '狂病': '/kuangbing/',
#  '情感性心境障碍': '/qingganxingxinjingzhangai/',
#  '小儿多动症': '/xiaoerduodongzheng/',
#  '女性性高潮障碍': '/nvxingxinggaochaozhangai/',
#  '偏执性精神障碍': '/pianzhixingjingshenzhangai/',
#  '儿童分离性焦虑障碍': '/ertongfenlixingjiaolvzhangai/',
#  '气功性精神障碍': '/qigongxingjingshenzhangai/',
#  '神经症': '/shenjingzheng/',
#  '童年情绪障碍': '/tongnianqingxuzhangai/',
#  '童年社会功能障碍': '/tongnianshehuigongnengzhangai/',
#  '网络成瘾': '/wangluochengzuo/',
#  '女子梦交': '/nvzimengjiao/',
#  '性厌恶': '/xingyane/',
#  '恐怖症': '/kongbuzheng/',
#  '梦魇': '/mengzuo/',
#  '性心理障碍': '/xingxinlizhangai/',
#  '心理应激': '/xinliyingji/',
#  '心身疾病': '/xinshenjibing/',
#  '性变态': '/xingbiantai/',
#  '性冷淡': '/xinglengdan/',
#  '小儿厌食症': '/xiaoeryanshizheng/',
#  '幻肢疼痛': '/huanzhitengtong/',
#  '躯体感觉障碍': '/qutiganjuezhangai/',
#  '儿童恐惧症': '/ertongkongjuzheng/',
#  '品行障碍': '/pinxingzhangai/',
#  '儿童口吃': '/ertongkouchi/',
#  '婚恋心理问题': '/hunlianxinliwenti/',
#  '烟酒依赖症': '/yanjiuyilaizheng/',
#  '儿童期情绪障碍': '/ertongqiqingxuzhangai/',
#  '围术期伴发的精神障碍': '/weishuqibanfadejingshenzhangai/',
#  '青少年心理叛逆': '/qingshaonianxinlipanni/',
#  '躁狂抑郁症': '/zaokuangyiyuzheng/',
#  '躯体形式障碍': '/qutixingshizhangai/',
#  '神经性厌食症': '/shenjingxingyanshizheng/',
#  '儿童强迫症': '/ertongqiangpozheng/',
#  '癫病': '/zuobing/',
#  '青春期厌食症': '/qingchunqiyanshizheng/',
#  '精神发育迟滞': '/jingshenfayuchizhi/',
#  '伪聋': '/weilong/',
#  '儿童社交恐惧症': '/ertongshejiaokongjuzheng/',
#  '旅途精神病': '/lvtujingshenbing/',
#  '缢死': '/zuosi/',
#  '双性恋': '/shuangxinglian/',
#  '神思间病': '/shensijianbing/',
#  '人格解体-现实解体综合征': '/rengejieti-xianshijietizonghezheng/',
#  '性功能异常伴发的精神障碍': '/xinggongnengyichangbanfadejingshenzhangai/',
#  '双相情感障碍': '/shuangxiangqingganzhangai/',
#  '屏幕脸': '/pingmulian/',
#  '老年神经症': '/laonianshenjingzheng/',
#  '神游症': '/shenyouzheng/',
#  '露阴癖': '/luyinzuo/',
#  '老年抑郁症': '/laonianyiyuzheng/',
#  '老年忧郁症': '/laonianyouyuzheng/',
#  '沮丧和情感淡漠': '/jusangheqinggandanmo/',
#  '分裂情感性障碍': '/fenlieqingganxingzhangai/',
#  '非依赖性物质伴发依赖': '/feiyilaixingwuzhibanfayilai/',
#  '性兴奋障碍': '/xingxingfenzhangai/',
#  '白血病伴发的精神障碍': '/baixuebingbanfadejingshenzhangai/',
#  '白塞病伴发的精神障碍': '/baisaibingbanfadejingshenzhangai/',
#  '病态人格': '/bingtairenge/',
#  '反社会人格障碍': '/fanshehuirengezhangai/',
#  '小儿分离性焦虑症': '/xiaoerfenlixingjiaolvzheng/',
#  '谵妄综合征': '/zuowangzonghezheng/',
#  '功能性聋': '/gongnengxinglong/'}

# %%
driver.get(url=url2)
page = driver.page_source
page_html = etree.HTML(page)
disease_name_list = page_html.xpath('/html/body/div[3]/div[1]/ul[2]/div/ul[2]/li/a/text()')
disease_urlpostfix_list = page_html.xpath('/html/body/div[3]/div[1]/ul[2]/div/ul[2]/li/a/@href')

# %%
for i in range(len(disease_name_list)):
    dic[disease_name_list[i]] = disease_urlpostfix_list[i]
dic
# Out:
# {'早恋': '/zaolian/',
#  '产后抑郁症': '/chanhouyiyuzheng/',
#  '癔症': '/zuozheng/',
#  '幻觉': '/huanjue/',
#  '意志缺乏症': '/yizhiquefazheng/',
#  '口吃': '/kouchi/',
#  '露阴症': '/luyinzheng/',
#  '强迫性障碍': '/qiangpoxingzhangai/',
#  '轻度抑郁发作': '/qingduyiyufazuo/',
#  '人格障碍': '/rengezhangai/',
#  '神经性厌食': '/shenjingxingyanshi/',
#  '神经衰弱': '/shenjingshuairuo/',
#  '社交恐惧症': '/shejiaokongjuzheng/',
#  '神经质': '/shenjingzhi/',
#  '贪食': '/tanshi/',
#  '性交疼痛': '/xingjiaotengtong/',
#  '抑郁症': '/yiyuzheng/',
#  '疑病症': '/yibingzheng/',
#  '厌食症 ': '/yanshizheng /',
#  '强迫症': '/qiangpozheng/',
#  '歇斯底里': '/xiesidili/',
#  '忧郁症': '/youyuzheng/',
#  '心理障碍': '/xinlizhangai/',
#  '重度抑郁症': '/zhongduyiyuzheng/',
#  '躁郁症': '/zaoyuzheng/',
#  '自闭症': '/zibizheng/',
#  '纤维肌痛综合症': '/xianweijitongzonghezheng/',
#  '恋物癖': '/lianwuzuo/',
#  '创伤后应激障碍': '/chuangshanghouyingjizhangai/',
#  '癫狂病': '/zuokuangbing/',
#  '儿童精神分裂症': '/ertongjingshenfenliezheng/',
#  '忽略症': '/huluezheng/',
#  '非器质性阴道痉挛': '/feiqizhixingyindaojingluan/',
#  '睡眠障碍': '/shuimianzhangai/',
#  '遗尿症': '/yiniaozheng/',
#  '恐怖性焦虑障碍': '/kongbuxingjiaolvzhangai/',
#  '狂病': '/kuangbing/',
#  '情感性心境障碍': '/qingganxingxinjingzhangai/',
#  '小儿多动症': '/xiaoerduodongzheng/',
#  '女性性高潮障碍': '/nvxingxinggaochaozhangai/',
#  '偏执性精神障碍': '/pianzhixingjingshenzhangai/',
#  '儿童分离性焦虑障碍': '/ertongfenlixingjiaolvzhangai/',
#  '气功性精神障碍': '/qigongxingjingshenzhangai/',
#  '神经症': '/shenjingzheng/',
#  '童年情绪障碍': '/tongnianqingxuzhangai/',
#  '童年社会功能障碍': '/tongnianshehuigongnengzhangai/',
#  '网络成瘾': '/wangluochengzuo/',
#  '女子梦交': '/nvzimengjiao/',
#  '性厌恶': '/xingyane/',
#  '恐怖症': '/kongbuzheng/',
#  '梦魇': '/mengzuo/',
#  '性心理障碍': '/xingxinlizhangai/',
#  '心理应激': '/xinliyingji/',
#  '心身疾病': '/xinshenjibing/',
#  '性变态': '/xingbiantai/',
#  '性冷淡': '/xinglengdan/',
#  '小儿厌食症': '/xiaoeryanshizheng/',
#  '幻肢疼痛': '/huanzhitengtong/',
#  '躯体感觉障碍': '/qutiganjuezhangai/',
#  '儿童恐惧症': '/ertongkongjuzheng/',
#  '品行障碍': '/pinxingzhangai/',
#  '儿童口吃': '/ertongkouchi/',
#  '婚恋心理问题': '/hunlianxinliwenti/',
#  '烟酒依赖症': '/yanjiuyilaizheng/',
#  '儿童期情绪障碍': '/ertongqiqingxuzhangai/',
#  '围术期伴发的精神障碍': '/weishuqibanfadejingshenzhangai/',
#  '青少年心理叛逆': '/qingshaonianxinlipanni/',
#  '躁狂抑郁症': '/zaokuangyiyuzheng/',
#  '躯体形式障碍': '/qutixingshizhangai/',
#  '神经性厌食症': '/shenjingxingyanshizheng/',
#  '儿童强迫症': '/ertongqiangpozheng/',
#  '癫病': '/zuobing/',
#  '青春期厌食症': '/qingchunqiyanshizheng/',
#  '精神发育迟滞': '/jingshenfayuchizhi/',
#  '伪聋': '/weilong/',
#  '儿童社交恐惧症': '/ertongshejiaokongjuzheng/',
#  '旅途精神病': '/lvtujingshenbing/',
#  '缢死': '/zuosi/',
#  '双性恋': '/shuangxinglian/',
#  '神思间病': '/shensijianbing/',
#  '人格解体-现实解体综合征': '/rengejieti-xianshijietizonghezheng/',
#  '性功能异常伴发的精神障碍': '/xinggongnengyichangbanfadejingshenzhangai/',
#  '双相情感障碍': '/shuangxiangqingganzhangai/',
#  '屏幕脸': '/pingmulian/',
#  '老年神经症': '/laonianshenjingzheng/',
#  '神游症': '/shenyouzheng/',
#  '露阴癖': '/luyinzuo/',
#  '老年抑郁症': '/laonianyiyuzheng/',
#  '老年忧郁症': '/laonianyouyuzheng/',
#  '沮丧和情感淡漠': '/jusangheqinggandanmo/',
#  '分裂情感性障碍': '/fenlieqingganxingzhangai/',
#  '非依赖性物质伴发依赖': '/feiyilaixingwuzhibanfayilai/',
#  '性兴奋障碍': '/xingxingfenzhangai/',
#  '白血病伴发的精神障碍': '/baixuebingbanfadejingshenzhangai/',
#  '白塞病伴发的精神障碍': '/baisaibingbanfadejingshenzhangai/',
#  '病态人格': '/bingtairenge/',
#  '反社会人格障碍': '/fanshehuirengezhangai/',
#  '小儿分离性焦虑症': '/xiaoerfenlixingjiaolvzheng/',
#  '谵妄综合征': '/zuowangzonghezheng/',
#  '功能性聋': '/gongnengxinglong/',
#  '身心疾病': '/shenxinjibing/',
#  '乙脑伴发的精神障碍': '/yinaobanfadejingshenzhangai/',
#  '非器质性性交疼痛': '/feiqizhixingxingjiaotengtong/',
#  '反应性精神病': '/fanyingxingjingshenbing/',
#  '小儿言语和语言障碍': '/xiaoeryanyuheyuyanzhangai/',
#  '办公室综合症': '/bangongshizonghezheng/',
#  '小儿学校恐怖症': '/xiaoerxuexiaokongbuzheng/',
#  '性病神经症': '/xingbingshenjingzheng/',
#  '学生心理问题': '/xueshengxinliwenti/',
#  '急性妄想发作': '/jixingwangxiangfazuo/',
#  '疾病恐怖': '/jibingkongbu/',
#  '广泛性焦虑障碍': '/guangfanxingjiaolvzhangai/',
#  '格斯特曼综合征': '/gesitemanzonghezheng/',
#  '性高潮障碍': '/xinggaochaozhangai/',
#  '急性心因性反应': '/jixingxinyinxingfanying/',
#  '抽动秽语综合征': '/choudonghuiyuzonghezheng/',
#  '系统性红斑狼疮伴发的精神障碍': '/xitongxinghongbanlangchuangbanfadejingshenzhangai/',
#  '广场恐惧症': '/guangchangkongjuzheng/',
#  '面红和面红恐惧症': '/mianhonghemianhongkongjuzheng/',
#  '惊恐障碍': '/jingkongzhangai/',
#  '惊恐症': '/jingkongzheng/',
#  '洁癖': '/jiezuo/',
#  '性施虐症与性受虐症': '/xingshinuezhengyuxingshounuezheng/',
#  '脑神经萎缩型脑瘫': '/naoshenjingweisuoxingnaotan/',
#  '摩擦症': '/mobazheng/',
#  '妄想性障碍': '/wangxiangxingzhangai/',
#  '婚外恋': '/hunwailian/',
#  '妄想型精神分裂症': '/wangxiangxingjingshenfenliezheng/',
#  '遗忘综合征': '/yiwangzonghezheng/',
#  '家庭心理问题': '/jiatingxinliwenti/',
#  '臭汗恐惧症': '/chouhankongjuzheng/',
#  '冲动控制障碍': '/chongdongkongzhizhangai/',
#  '农药中毒所致的精神障碍': '/nongyaozhongdusuozhidejingshenzhangai/',
#  '考后综合症': '/kaohouzonghezheng/',
#  '酒精戒断综合征': '/jiujingjieduanzonghezheng/',
#  '急性应激反应': '/jixingyingjifanying/',
#  '进食障碍': '/jinshizhangai/',
#  '拔毛狂': '/bamaokuang/',
#  '小儿精神发育迟缓': '/xiaoerjingshenfayuchihuan/',
#  '小儿孤独症': '/xiaoerguduzheng/',
#  '绝经与抑郁症': '/juejingyuyiyuzheng/',
#  '性障碍': '/xingzhangai/',
#  '致死性家族性失眠症': '/zhisixingjiazuxingshimianzheng/',
#  '恐缩症': '/kongsuozheng/',
#  '言语和语言发育障碍': '/yanyuheyuyanfayuzhangai/',
#  '窥阴癖': '/kuiyinzuo/',
#  '空巢综合症': '/kongchaozonghezheng/',
#  '应激反应及适应障碍': '/yingjifanyingjishiyingzhangai/',
#  '延迟性应激反应': '/yanchixingyingjifanying/',
#  '恋物症': '/lianwuzheng/',
#  '呼吸系统疾病伴发的精神障碍': '/huxixitongjibingbanfadejingshenzhangai/',
#  '失恋': '/shilian/',
#  '失眠抑郁': '/shimianyiyu/',
#  '延迟性心因性反应': '/yanchixingxinyinxingfanying/',
#  '学习技能发育障碍': '/xuexijinengfayuzhangai/',
#  '性身份障碍': '/xingshenfenzhangai/',
#  '注意缺陷障碍': '/zhuyiquexianzhangai/',
#  '脏躁': '/zangzao/',
#  '脑垂体功能异常伴发的精神障碍': '/naochuitigongnengyichangbanfadejingshenzhangai/',
#  '阴道痉挛': '/yindaojingluan/',
#  '言语障碍': '/yanyuzhangai/',
#  '癔症性失声': '/zuozhengxingshisheng/',
#  '异装症': '/yizhuangzheng/',
#  '癔病性昏厥': '/zuobingxinghunzuo/',
#  '郁证': '/yuzheng/',
#  '恐惧症': '/kongjuzheng/',
#  '感应性妄想性障碍': '/ganyingxingwangxiangxingzhangai/',
#  '适应障碍': '/shiyingzhangai/',
#  '偏执狂': '/pianzhikuang/',
#  '偏执状态': '/pianzhizhuangtai/',
#  '急性短暂性精神障碍': '/jixingduanzanxingjingshenzhangai/',
#  '寄生虫妄想': '/jishengchongwangxiang/',
#  '窥阴症': '/kuiyinzheng/',
#  '应激障碍': '/yingjizhangai/',
#  '厌学': '/yanxue/',
#  '产后失眠': '/chanhoushimian/'}

# %%
len(dic)
# Out:
# 176

# %%
dic

# %%
url_prefix = 'http://jibing.wenyw.com'
import json

# %%
with open('data.json', 'w', encoding='utf-8') as f:
    json_dic = {}
    for key, val in dic.items():
        url = url_prefix + val
        disease_info_dic = {}
        driver.get(url=url)
        page = driver.page_source
        page_html = etree.HTML(page)
        disease_info_dic['disease_name'] = key
        pathogenic_site = page_html.xpath('/html/body/div[3]/div[2]/ul[1]/div[2]/ul[1]/div/dl/dd/a/text()')
        disease_info_dic['pathogenic_site'] = pathogenic_site[0]
        department = page_html.xpath('/html/body/div[3]/div[2]/ul[1]/div[2]/ul[1]/dl[1]/dd/a/text()')
        # 这里需要验证数组的大小
        if len(department) == 1:
            disease_info_dic['department'] = department[0]
        else:
            disease_info_dic['department'] = ','.join(department)

        symptom = page_html.xpath('/html/body/div[3]/div[2]/ul[1]/div[2]/ul[1]/dl[2]/dd/text()')
        disease_info_dic['symptom'] = symptom[0] if len(symptom) != 0 else None
        check = page_html.xpath('/html/body/div[3]/div[2]/ul[1]/div[2]/ul[1]/dl[3]/dd/text()')
        disease_info_dic['check'] = check[0] if len(check) != 0 else None
        infectivity = page_html.xpath('/html/body/div[3]/div[2]/ul[1]/div[2]/ul[1]/dl[4]/dd/text()')
        disease_info_dic['infectivity'] = infectivity[0] if len(infectivity) != 0 else None
        heredity = page_html.xpath('/html/body/div[3]/div[2]/ul[1]/div[2]/ul[1]/dl[5]/dd/text()')
        disease_info_dic['heredity'] = heredity[0] if len(heredity) != 0 else None
        confusable_disease = page_html.xpath('/html/body/div[3]/div[2]/ul[1]/div[2]/ul[1]/dl[6]/dd/text()')
        disease_info_dic['confusable_disease'] = confusable_disease[0] if len(confusable_disease) != 0 else None
        susceptible_crowd = page_html.xpath('/html/body/div[3]/div[2]/ul[1]/div[2]/ul[1]/dl[7]/dd/text()')
        disease_info_dic['susceptible_crowd'] = susceptible_crowd[0] if len(susceptible_crowd) != 0 else None
        expert_remind = page_html.xpath('/html/body/div[3]/div[2]/ul[1]/div[2]/ul[2]/text()')
        json_dic[key] = disease_info_dic

# %%
json_dic
# Out:
# {'早恋': {'disease_name': '早恋',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '性早熟',
#   'check': '心理咨询',
#   'infectivity': '早孕',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神障碍'},
#  '产后抑郁症': {'disease_name': '产后抑郁症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '抑郁症、愉快感缺乏、失眠、单次发作抑郁症、沮丧、思维紊乱、产后肥胖、思考困难感、产后抑郁症、决断困难感、抑郁性木僵、进食异常、不真实感、川字纹',
#   'check': '头部B超、头部MRI、脑电图(EEG)',
#   'infectivity': '失眠、焦虑障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '焦虑症'},
#  '癔症': {'disease_name': '癔症',
#   'pathogenic_site': '全身',
#   'department': '中医内科',
#   'symptom': '紫绀、关节肿痛',
#   'check': '中医诊断',
#   'infectivity': '心悸、神昏',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '瘀斑、血瘀'},
#  '幻觉': {'disease_name': '幻觉',
#   'pathogenic_site': '头颈部',
#   'department': '精神病科,心理咨询科',
#   'symptom': '易激动、幻觉、入睡幻觉、梦幻觉',
#   'check': '头部B超、头部MRI、脑电图(EEG)',
#   'infectivity': '精神分裂症、癔症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '癫痫、酒精中毒、精神分裂症'},
#  '意志缺乏症': {'disease_name': '意志缺乏症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '谵妄、嗜睡、情感淡漠、思维贫乏',
#   'check': None,
#   'infectivity': None,
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '闭锁综合征、木僵、抑郁症'},
#  '口吃': {'disease_name': '口吃',
#   'pathogenic_site': '头颈部',
#   'department': '心理咨询科,神经内科',
#   'symptom': '讷吃、言语表达障碍、口齿不清、口吃、语言发育迟缓、构音困难现象',
#   'check': '头部B超、头部MRI、头部CT',
#   'infectivity': '功能性遗尿、睡眠障碍、心因性无食欲',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '言语障碍'},
#  '露阴症': {'disease_name': '露阴症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '露阴癖、精神变态',
#   'check': '心理咨询',
#   'infectivity': '抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '恋物癖'},
#  '强迫性障碍': {'disease_name': '强迫性障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '强迫行为、强迫观念、强迫性性行为、强迫性联想、强迫型人格障碍',
#   'check': '头部MRI、头部CT',
#   'infectivity': '失眠、营养不良、抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、社交恐惧症、抑郁症'},
#  '轻度抑郁发作': {'disease_name': '轻度抑郁发作',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '抑郁症、无用感、忧郁思虑、食欲减退、思考困难感',
#   'check': '脑电图(EEG)',
#   'infectivity': '失眠、食欲缺乏、头痛',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '焦虑症、神经衰弱'},
#  '人格障碍': {'disease_name': '人格障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '抑郁、心境高涨、猜疑、善怒',
#   'check': '头部MRI、头部CT、脑电图(EEG)',
#   'infectivity': '抑郁症、狂躁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '偏执性精神障碍'},
#  '神经性厌食': {'disease_name': '神经性厌食',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,消化内科',
#   'symptom': '食欲减退、夏季厌食、消瘦、营养不良、餐后即刻呕吐、进食异常、夏季厌食症、毛发呈脱发样、外源性消瘦、食欲异常',
#   'check': '血常规、头部CT、脑电图(EEG)',
#   'infectivity': '闭经、低血压、发育障碍、营养性消瘦',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、脑肿瘤、抑郁症、原发性小肠吸收不良综合征'},
#  '神经衰弱': {'disease_name': '神经衰弱',
#   'pathogenic_site': '头颈部',
#   'department': '心理咨询科,中医内科,神经内科',
#   'symptom': '注意力不集中、睡眠障碍、易激惹、头晕、疲乏',
#   'check': '头部CT、心电图、脑电图(EEG)',
#   'infectivity': '焦虑症、抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '动脉硬化性脑病、精神分裂症、焦虑症、颅内占位性病变、颅内感染、抑郁症、慢性疲劳综合症'},
#  '社交恐惧症': {'disease_name': '社交恐惧症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,神经内科',
#   'symptom': '恐惧、坐立不安、善忧思、脸红、善恐、善惊、疥疮恐惧、社交恐惧、体象障碍、产后抑郁症、晕血、轻度失眠',
#   'check': '头部CT、脑电图(EEG)',
#   'infectivity': '头痛、心悸',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '惊恐障碍[间歇发作性焦虑]'},
#  '神经质': {'disease_name': '神经质',
#   'pathogenic_site': '头颈部',
#   'department': '精神病科,心理咨询科',
#   'symptom': '无能力感、头摇、赔偿性神经症、感觉过度、舌震颤、紧张、行为及情绪异常、神经质性格、厌食、精神过敏、信息成瘾、间歇性耳聋、感觉倒错、癔症步态、烦躁不安、失眠、灾难反应、易醒、意向倒错、夸大狂、燥狂相、喜讲秽语、心境高涨、痛阈降低、听觉过敏、食欲异常、性受虐癖、疑病症、轻度失眠',
#   'check': '头部MRI、头部CT、脑电图(EEG)',
#   'infectivity': '便秘、失眠、抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '周围神经病、精神病'},
#  '贪食': {'disease_name': '贪食',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,消化内科',
#   'symptom': '食积痛、贪食症、便下恶臭、体重增加、贪食行为、多食、放屁过臭、婴儿过胖、易饿、中度肥胖、食欲异常',
#   'check': '血常规、头部MRI',
#   'infectivity': '肥胖症、抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '甲状腺机能亢进症'},
#  '性交疼痛': {'disease_name': '性交疼痛',
#   'pathogenic_site': '腹部',
#   'department': '妇科,心理咨询科,泌尿外科',
#   'symptom': '性交困难、刺痛、外阴烧灼刺激感、性交疼痛、钝痛',
#   'check': '前列腺及精囊腺B超、盆腔及阴道B超、阴道镜、阴道分泌物检测',
#   'infectivity': '性高潮功能障碍、勃起功能障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '尿路感染、阴道痉挛'},
#  '抑郁症': {'disease_name': '抑郁症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科',
#   'symptom': '沮丧、精神萎靡、呆滞、思维缓慢、情感淡漠、情绪低落',
#   'check': '脑脊液检测、头部MRI、脑电图(EEG)',
#   'infectivity': '便秘、焦虑症、睡眠障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、偏执型精神分裂症、心理障碍'},
#  '疑病症': {'disease_name': '疑病症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '恶心、呼吸困难、胸痛、心悸、腹泻、疼痛',
#   'check': None,
#   'infectivity': '焦虑症、抑郁症、强迫症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、神经衰弱、躁狂状态'},
#  '厌食症 ': {'disease_name': '厌食症 ',
#   'pathogenic_site': '全身',
#   'department': '营养科,心理咨询科,神经内科',
#   'symptom': '食欲异常、营养不良、消瘦',
#   'check': '头部MRI、头部CT、脑电图(EEG)',
#   'infectivity': '低血压、贫血、生长发育迟缓、营养不良',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、脑肿瘤、消化不良、抑郁症'},
#  '强迫症': {'disease_name': '强迫症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '强迫观念、强迫性重复、强迫行为',
#   'check': '血常规、脑电图(EEG)',
#   'infectivity': '抽动障碍、焦虑症、人格障碍、精神病',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、抑郁症'},
#  '歇斯底里': {'disease_name': '歇斯底里',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '言语错乱、意识障碍、感觉过敏、自杀行为、运动障碍',
#   'check': '血常规、头部CT、脑电图(EEG)',
#   'infectivity': '焦虑症、人格障碍、神经衰弱、抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '反应性精神病、精神分裂症'},
#  '忧郁症': {'disease_name': '忧郁症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '忧郁、阳气郁伏、发作后精神障碍、情感淡漠、忧郁思虑、胸闷长叹息气短、喜叹息、思维缓慢、被窃或疑病妄想、决断困难感、听觉过敏、信息成瘾',
#   'check': '脑脊液检测、头部MRI、脑电图(EEG)',
#   'infectivity': '焦虑症、睡眠障碍、心悸、性欲减退',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、器质性精神障碍'},
#  '心理障碍': {'disease_name': '心理障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医精神科',
#   'symptom': '品行障碍、智力减低、抑郁、妄想、幻觉、焦虑',
#   'check': '头部CT、脑电图(EEG)、心理咨询',
#   'infectivity': '幻听、幻视、妄想狂',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '个人心理成长'},
#  '重度抑郁症': {'disease_name': '重度抑郁症',
#   'pathogenic_site': '头颈部',
#   'department': '心理咨询科,神经内科',
#   'symptom': '抑郁症、反复发作抑郁症、愉快感缺乏、忧郁思虑、思维缓慢、失眠、情感淡漠、思考困难感、决断困难感、抑郁性木僵、不真实感',
#   'check': '血常规、头部MRI、脑电图(EEG)',
#   'infectivity': '睡眠障碍、性欲减退',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、神经官能症'},
#  '躁郁症': {'disease_name': '躁郁症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '心烦、言语增多、运动性兴奋或抑郁、运动障碍疾病、心境高涨、躁郁样、烦躁不安、抑郁、喜怒无常',
#   'check': '头部MRI、头部CT、脑电图(EEG)',
#   'infectivity': '精神分裂症、躁狂状态',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '神经衰弱、抑郁症、躁狂状态'},
#  '自闭症': {'disease_name': '自闭症',
#   'pathogenic_site': '全身',
#   'department': '儿科,精神病科,心理咨询科,小儿精神科',
#   'symptom': '节律性刻板重复的不自主运动、对生活丧失兴趣、社交恐惧',
#   'check': '头部CT、脑电图(EEG)',
#   'infectivity': '癫痫、智力低下、儿童攻击行为',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '阿斯伯格综合症、儿童精神分裂症、小儿精神发育迟缓'},
#  '纤维肌痛综合症': {'disease_name': '纤维肌痛综合症',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,中医内科,神经内科',
#   'symptom': '肌肉压痛、睡眠障碍、肌肤疼痛、晨僵、疲乏',
#   'check': '血常规、脑脊液检测',
#   'infectivity': '焦虑症、头痛、抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '风湿性多肌痛、类风湿关节炎、慢性疲劳综合征'},
#  '恋物癖': {'disease_name': '恋物癖',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,成瘾医学科',
#   'symptom': '迷恋足部或鞋袜',
#   'check': None,
#   'infectivity': '早泄、窥阴癖、露阴癖',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '恋物性异装症、易性症、性变态'},
#  '创伤后应激障碍': {'disease_name': '创伤后应激障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '噩梦、惊跳、恐惧、面色苍白、气短',
#   'check': '心理咨询',
#   'infectivity': '抑郁症、延迟性应激反应',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神障碍'},
#  '癫狂病': {'disease_name': '癫狂病',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科',
#   'symptom': '情感高涨、情绪低落、睡眠障碍',
#   'check': '血常规、头部MRI、头部CT、脑电图(EEG)、心理咨询',
#   'infectivity': '睡眠障碍、心脏病',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '癫病、狂病、脏躁'},
#  '儿童精神分裂症': {'disease_name': '儿童精神分裂症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科,小儿精神科',
#   'symptom': '睡眠障碍、注意力不集中、儿童行为孤僻、紧张、伴有生动鲜明的恐怖性幻视、口齿含糊、被害妄想',
#   'check': '头部MRI、头部CT、脑电图(EEG)',
#   'infectivity': '精神衰弱',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '童年社交焦虑障碍、小儿多动症、儿童情绪障碍、儿童孤独症、小儿精神发育迟缓'},
#  '忽略症': {'disease_name': '忽略症',
#   'pathogenic_site': '头颈部',
#   'department': '精神病科,心理咨询科',
#   'symptom': '偏侧不注意、垂直性忽略症、感觉障碍、偏侧空间忽略症、偏盲、运动性忽略症',
#   'check': '头部CT',
#   'infectivity': '肺部感染、尿路感染、偏执狂',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '颅内肿瘤'},
#  '非器质性阴道痉挛': {'disease_name': '非器质性阴道痉挛',
#   'pathogenic_site': '腹部',
#   'department': '心理咨询科',
#   'symptom': '肝郁气滞阴痛、阴道闭锁',
#   'check': '肌电图',
#   'infectivity': '阴道闭锁',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '性交疼痛'},
#  '睡眠障碍': {'disease_name': '睡眠障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,神经内科',
#   'symptom': '缺乏深睡眠、睡眠不足、夜寐不实、白天嗜睡夜间失眠、白天睡眠过度',
#   'check': '头部MRI、心电图、脑电图(EEG)、血液检查、CT、神经心理学测验',
#   'infectivity': '精神衰弱',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '失眠'},
#  '遗尿症': {'disease_name': '遗尿症',
#   'pathogenic_site': '腹部',
#   'department': '心理咨询科,肾内科',
#   'symptom': '排尿困难、尿频、尿急、尿流变细或中断',
#   'check': '尿液检测、肾脏及输尿管B超、脑电图(EEG)、X线平片、血液检查',
#   'infectivity': '精神分裂症、发育迟缓',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '尿失禁'},
#  '恐怖性焦虑障碍': {'disease_name': '恐怖性焦虑障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '惊恐反应现象、儿童恐怖症、坐立不安、善恐、场所恐惧、麻风恐怖、惊恐发作、晕血、步态不稳、颤抖、呼吸困难、焦虑性适应障碍、紧张',
#   'check': '心理咨询',
#   'infectivity': '社交恐怖、抑郁倾向',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '焦虑症'},
#  '狂病': {'disease_name': '狂病',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科',
#   'symptom': '精神异常、哭笑失常、谵妄、行为及情绪异常、秋季狂躁症、技术狂躁症',
#   'check': '脑电图(EEG)、中医诊断',
#   'infectivity': '癫痫',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症'},
#  '情感性心境障碍': {'disease_name': '情感性心境障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科',
#   'symptom': '情感高涨、抑郁、思维缓慢、情绪低落、易激动',
#   'check': '血常规',
#   'infectivity': '痴呆',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '痴呆、精神分裂症、神经衰弱'},
#  '小儿多动症': {'disease_name': '小儿多动症',
#   'pathogenic_site': '头颈部',
#   'department': '心理咨询科,小儿精神科,小儿神经内科',
#   'symptom': '不断眨眼、单侧及假性手足徐动、腹壁不自主轴动、情绪不宁、新生儿手足徐动、注意力不集中',
#   'check': '神经系统检查',
#   'infectivity': '情感障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '发育障碍、精神障碍、精神发育迟缓'},
#  '女性性高潮障碍': {'disease_name': '女性性高潮障碍',
#   'pathogenic_site': '腹部',
#   'department': '妇科,心理咨询科',
#   'symptom': '充血、四肢肌张力增强、阴道分泌物增多',
#   'check': '性腺激素检测、心理咨询',
#   'infectivity': '性欲缺失',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '性功能障碍'},
#  '偏执性精神障碍': {'disease_name': '偏执性精神障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '被害妄想、抑郁、疑病症、妄想',
#   'check': None,
#   'infectivity': '强迫症、妄想症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、偏执型人格障碍'},
#  '儿童分离性焦虑障碍': {'disease_name': '儿童分离性焦虑障碍',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,小儿精神科',
#   'symptom': '脾气变坏、恶心、头痛、烦躁不安',
#   'check': '神经系统检查',
#   'infectivity': '恐惧症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '广泛性焦虑障碍、儿童恐惧症、小儿学校恐怖症'},
#  '气功性精神障碍': {'disease_name': '气功性精神障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科',
#   'symptom': '四肢麻木、腹痛、腹胀、头晕、头痛',
#   'check': '神经心理学测验',
#   'infectivity': '精神障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、癔症'},
#  '神经症': {'disease_name': '神经症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,神经内科',
#   'symptom': '脾气变坏、对生活丧失兴趣、儿童恐怖症、呼吸困难、紧张、恐惧',
#   'check': '神经系统检查',
#   'infectivity': '便秘、遗精',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '反应性精神病、感染性精神病'},
#  '童年情绪障碍': {'disease_name': '童年情绪障碍',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,小儿精神科',
#   'symptom': '恶心、噩梦、烦躁不安、腹痛、攻击行为',
#   'check': '心理咨询',
#   'infectivity': '抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '情绪不稳型人格障碍'},
#  '童年社会功能障碍': {'disease_name': '童年社会功能障碍',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,小儿精神科',
#   'symptom': '缄默症、精神异常、恐惧、抑郁、易激惹',
#   'check': '心理咨询',
#   'infectivity': '焦虑症、抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '社会化品行障碍'},
#  '网络成瘾': {'disease_name': '网络成瘾',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,成瘾医学科',
#   'symptom': '思维缓慢、情绪低落、睡眠障碍',
#   'check': None,
#   'infectivity': '精神损伤',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '心理障碍'},
#  '女子梦交': {'disease_name': '女子梦交',
#   'pathogenic_site': '头颈部',
#   'department': '精神病科,心理咨询科,中医内科,神经内科',
#   'symptom': '精神过敏、头痛、头晕、喜怒无常',
#   'check': '头部CT、神经系统检查、心理咨询',
#   'infectivity': '精神分裂症、颅咽管瘤、副鼻窦炎、脑动静脉畸形',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': None},
#  '性厌恶': {'disease_name': '性厌恶',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '恐惧、性交困难、性欲减退',
#   'check': '血常规',
#   'infectivity': '心理障碍、不孕不育症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '性功能障碍'},
#  '恐怖症': {'disease_name': '恐怖症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '恐惧、紧张、社交恐惧',
#   'check': None,
#   'infectivity': '情绪障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '精神分裂症、焦虑症、疑病症、强迫症'},
#  '梦魇': {'disease_name': '梦魇',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '疲劳、出冷汗、面色苍白',
#   'check': None,
#   'infectivity': '呼吸困难、疲劳综合征、消化不良',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '惊厥、惊恐症、夜惊'},
#  '性心理障碍': {'disease_name': '性心理障碍',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '露阴癖、性施虐癖、性受虐癖',
#   'check': None,
#   'infectivity': '婚恋心理问题',
#   'heredity': '该病具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '恋物症、人格障碍、易性症'},
#  '心理应激': {'disease_name': '心理应激',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '睡眠障碍、食欲减退、情绪不宁、注意力不集中、惊跳',
#   'check': None,
#   'infectivity': '高血压、冠心病、心律失常、应激性溃疡',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '癔症、创伤后应激障碍、分裂情感性障碍'},
#  '心身疾病': {'disease_name': '心身疾病',
#   'pathogenic_site': '全身',
#   'department': '普通外科,精神病科,心理咨询科,中医内科',
#   'symptom': '心理伤害',
#   'check': '甲状腺及甲状旁腺B超、心理咨询',
#   'infectivity': '精神障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': None},
#  '性变态': {'disease_name': '性变态',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '易性别癖、性受虐癖、性施虐癖、性窒息、异装癖、窥淫癖、露阴癖',
#   'check': '心电图',
#   'infectivity': '早泄、阳痿、恐惧症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '人格障碍、性偏好障碍、心理障碍'},
#  '性冷淡': {'disease_name': '性冷淡',
#   'pathogenic_site': '臀部',
#   'department': '妇科,男科,心理咨询科',
#   'symptom': '性交疼痛、阴道干涩、快感缺乏、恐惧',
#   'check': None,
#   'infectivity': '性功能障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '性欲减退、早泄、阳痿'},
#  '小儿厌食症': {'disease_name': '小儿厌食症',
#   'pathogenic_site': '腹部',
#   'department': '心理咨询科,消化内科,小儿消化科,小儿营养保健科',
#   'symptom': '便血、低热、反应迟钝、骨软化、精神萎靡、拒食、溃疡',
#   'check': '胃镜',
#   'infectivity': '发育障碍、营养不良',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '缺铁性贫血、寄生虫病'},
#  '幻肢疼痛': {'disease_name': '幻肢疼痛',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,针灸按摩科,神经内科',
#   'symptom': None,
#   'check': '神经系统检查、心理咨询',
#   'infectivity': None,
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '躯体感觉障碍'},
#  '躯体感觉障碍': {'disease_name': '躯体感觉障碍',
#   'pathogenic_site': '全身',
#   'department': '康复科,心理咨询科,神经内科',
#   'symptom': '放射性疼痛、感觉障碍、对侧躯体痛温觉减退或缺失、对侧上肢或下肢感觉缺失',
#   'check': '脑脊液检测、头部B超、头部MRI、头部CT、心电图、X线平片',
#   'infectivity': '脊髓空洞症、多发性神经病、髓内肿瘤',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '小儿格林巴利综合症、椎管内神经鞘瘤'},
#  '儿童恐惧症': {'disease_name': '儿童恐惧症',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,小儿精神科,小儿神经内科',
#   'symptom': '呼吸急促、恐惧、心慌',
#   'check': '神经系统检查、心理咨询',
#   'infectivity': '焦虑症、疑病症、强迫症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '焦虑症、疑病症、儿童强迫症、儿童精神分裂症、颞叶癫痫'},
#  '品行障碍': {'disease_name': '品行障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '暴怒、猥亵行为、抑郁、易激惹、病理性偷窃',
#   'check': '心理咨询',
#   'infectivity': None,
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、心境障碍、小儿多动症、精神发育迟滞、脑器质性精神障碍'},
#  '儿童口吃': {'disease_name': '儿童口吃',
#   'pathogenic_site': '头颈部',
#   'department': '心理咨询科,小儿精神科,小儿神经内科',
#   'symptom': '情绪障碍、言语表达障碍',
#   'check': '神经系统检查、心理咨询',
#   'infectivity': '神经质、儿童睡眠障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': None},
#  '婚恋心理问题': {'disease_name': '婚恋心理问题',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '情绪不宁、思维奔逸、幻觉、抑郁、易激动',
#   'check': '神经系统检查、心理咨询',
#   'infectivity': '抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '反应性精神病、精神分裂症、神经衰弱、精神病'},
#  '烟酒依赖症': {'disease_name': '烟酒依赖症',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,中医内科,成瘾医学科',
#   'symptom': '注意力不集中、善怒、焦虑、烦躁不安、失眠、震颤、不可克制的饮酒',
#   'check': '心理咨询',
#   'infectivity': '白血病、肺炎、高血压、肝功能不全、贫血、器质性阳萎、哮喘、消化性溃疡、营养不良、牙周病、周围血管病、主动脉瘤、中风、癌症、血栓闭塞性脉管炎',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '酒精中毒、毒瘾'},
#  '儿童期情绪障碍': {'disease_name': '儿童期情绪障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科,小儿精神科',
#   'symptom': '对生活丧失兴趣、情感暴发、恐惧、儿童退缩行为、强迫行为、意识朦胧状态、情绪低落',
#   'check': '神经系统检查、心理咨询',
#   'infectivity': '人格障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '双相性情感障碍、小儿多动症、儿童精神分裂症、小儿精神发育迟缓'},
#  '围术期伴发的精神障碍': {'disease_name': '围术期伴发的精神障碍',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '猜疑、反应迟钝、幻觉、紧张、精神异常、沮丧、恐惧',
#   'check': '脑脊液检测、头部CT',
#   'infectivity': '睡眠障碍、头痛、高血压脑病',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症'},
#  '青少年心理叛逆': {'disease_name': '青少年心理叛逆',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '烦躁不安',
#   'check': '心理咨询',
#   'infectivity': '心理障碍、病态人格、偏执性精神障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '社交恐惧症、心理障碍'},
#  '躁狂抑郁症': {'disease_name': '躁狂抑郁症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '抑郁、烦躁不安、情绪低落',
#   'check': None,
#   'infectivity': None,
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '精神分裂症、酒精中毒性精神障碍、神经衰弱'},
#  '躯体形式障碍': {'disease_name': '躯体形式障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科,神经内科',
#   'symptom': '头痛、焦虑、便秘、抑郁、心悸、头晕、食欲缺乏',
#   'check': '心理咨询',
#   'infectivity': '妄想狂',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '精神分裂症、焦虑症、抑郁症、恐惧症'},
#  '神经性厌食症': {'disease_name': '神经性厌食症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,神经内科,特色医疗科',
#   'symptom': '闭经、阳痿、消瘦、食欲减退、抑郁',
#   'check': '头部MRI、头部CT、心电图、脑电图(EEG)、X线平片',
#   'infectivity': '便秘、失眠、低血压、贫血、脱水、胃炎、头晕',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '精神分裂症、躯体化障碍、抑郁症、生理性厌食'},
#  '儿童强迫症': {'disease_name': '儿童强迫症',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,小儿精神科',
#   'symptom': '强迫行为、强迫观念',
#   'check': '血常规、心电图',
#   'infectivity': '强迫性动作、强迫性思维',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '强迫性障碍、强迫型人格障碍'},
#  '癫病': {'disease_name': '癫病',
#   'pathogenic_site': '全身',
#   'department': '中医内科',
#   'symptom': '肌肉萎缩、疲劳、瘫痪、无力、胸肌萎缩、大腿肌肉萎缩、手内肌萎缩、面肌萎缩、肩带肌、上肢和胸背部诸肌的肌无力和肌萎缩',
#   'check': '血常规、尿液检测、脑脊液检测',
#   'infectivity': '肌无力危象',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '痹证'},
#  '青春期厌食症': {'disease_name': '青春期厌食症',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,消化内科,神经内科',
#   'symptom': '身体瘦弱、皮肤干燥、月经过少、神经性厌食、体重减轻、拒食',
#   'check': '血常规、尿液检测、心电图、粪便检测、血清电解质检测、超声心动图',
#   'infectivity': '营养不良、心脏衰竭、感染性疾病',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '继发闭经、进食障碍'},
#  '精神发育迟滞': {'disease_name': '精神发育迟滞',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科,神经内科',
#   'symptom': '智力发育迟缓、言语功能的部分丧失',
#   'check': '头部CT、脑电图(EEG)、染色体检测、神经系统检查、血液生化检测',
#   'infectivity': '人格障碍、智力低下',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '混合性特定性发育障碍、小儿多动症、发育迟缓、儿童孤独症、儿童精神分裂症'},
#  '伪聋': {'disease_name': '伪聋',
#   'pathogenic_site': '头颈部',
#   'department': '心理咨询科,耳鼻喉科',
#   'symptom': '耳聋、听力减退、听力下降',
#   'check': '听力检查',
#   'infectivity': '突发性耳聋',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '突发性耳聋'},
#  '儿童社交恐惧症': {'disease_name': '儿童社交恐惧症',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,小儿精神科,小儿神经内科',
#   'symptom': '紧张、场所恐惧',
#   'check': '心理咨询',
#   'infectivity': '疑病症、儿童分离性焦虑障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '焦虑症、疑病症、儿童强迫症、颞叶癫痫'},
#  '旅途精神病': {'disease_name': '旅途精神病',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '被害妄想、痴笑、幻听、幻味、疲劳、意识障碍、忧郁',
#   'check': '脑电图(EEG)',
#   'infectivity': None,
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、情感障碍'},
#  '缢死': {'disease_name': '缢死',
#   'pathogenic_site': '全身',
#   'department': '急诊科,心血管内科',
#   'symptom': '运动性猝死、呼吸困难、心肌细胞的浊肿、猝死、血压下降、瞳孔扩大、心脏骤停、光反应消失、性交猝死、血压为零、噎食性猝死、心肺复苏术',
#   'check': '心电图、脑电图(EEG)',
#   'infectivity': '呼吸停止、呼吸心跳骤停',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '低血糖症、肺栓塞、心脏病'},
#  '双性恋': {'disease_name': '双性恋',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '性倒错',
#   'check': '脑电图(EEG)',
#   'infectivity': '心理障碍、婚恋心理问题',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '恋物癖'},
#  '神思间病': {'disease_name': '神思间病',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '抑郁',
#   'check': '脑电图(EEG)',
#   'infectivity': '精神障碍、妄想症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、精神衰弱'},
#  '人格解体-现实解体综合征': {'disease_name': '人格解体-现实解体综合征',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '现实解体、人格解体、恐惧、焦虑、情绪障碍、头晕',
#   'check': '血常规、脑脊液检测、头部MRI、头部CT、脑电图(EEG)、心理咨询',
#   'infectivity': '心悸、头晕',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、抑郁症'},
#  '性功能异常伴发的精神障碍': {'disease_name': '性功能异常伴发的精神障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '产褥期躁狂状态、失眠、焦虑、抑郁、易激惹、头痛',
#   'check': '脑电图(EEG)、彩色多普勒超声（彩超）、核磁共振（MRI）',
#   'infectivity': '精神病',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、抑郁症、癔症'},
#  '双相情感障碍': {'disease_name': '双相情感障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '躁狂与昏睡交替、抑郁',
#   'check': '甲状腺激素检测、神经系统检查、心理咨询',
#   'infectivity': '轻躁狂',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、人格障碍'},
#  '屏幕脸': {'disease_name': '屏幕脸',
#   'pathogenic_site': '头颈部',
#   'department': '精神病科,心理咨询科',
#   'symptom': '面部皮肤皱纹增多、面部斑、表情迟钝、表情淡漠',
#   'check': None,
#   'infectivity': '人格障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '面瘫'},
#  '老年神经症': {'disease_name': '老年神经症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,老年病科',
#   'symptom': '便秘、创伤、多梦、腹部不适、喉部堵塞感、喉头发紧、紧张性头痛',
#   'check': '血常规、心电图',
#   'infectivity': '心律失常、急性全自主神经失调症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '抑郁症、脑动脉硬化症'},
#  '神游症': {'disease_name': '神游症',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,神经内科',
#   'symptom': '抑郁、梦游',
#   'check': '心电图、脑电图(EEG)',
#   'infectivity': '失眠、睡眠障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '癫痫、梦魇'},
#  '露阴癖': {'disease_name': '露阴癖',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '窥淫癖、心理性性功能障碍、灌肠癖',
#   'check': '头部MRI、脑电图(EEG)',
#   'infectivity': None,
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '颞叶癫痫'},
#  '老年抑郁症': {'disease_name': '老年抑郁症',
#   'pathogenic_site': '头颈部',
#   'department': '心理咨询科,老年病科',
#   'symptom': '情绪不宁、神疲乏力、易激动、失眠',
#   'check': '血常规、尿液检测、普通透视检查',
#   'infectivity': '便秘、失眠、心血管疾病',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '痴呆、晚发性精神分裂症'},
#  '老年忧郁症': {'disease_name': '老年忧郁症',
#   'pathogenic_site': '头颈部',
#   'department': '心理咨询科,老年病科',
#   'symptom': '情绪不宁、易激动、神疲乏力、失眠',
#   'check': '血常规、尿液检测、普通透视检查',
#   'infectivity': '便秘、失眠、心血管疾病',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '痴呆、晚发性精神分裂症'},
#  '沮丧和情感淡漠': {'disease_name': '沮丧和情感淡漠',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '抑郁性神经症、表情淡漠、毫无情感反应',
#   'check': '头部B超、头部MRI、脑电图(EEG)',
#   'infectivity': '失眠、营养不良',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '痴呆、抑郁症'},
#  '分裂情感性障碍': {'disease_name': '分裂情感性障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '被害妄想、幻觉、幻听、精神异常、抑郁、分裂型人格障碍、毫无情感反应',
#   'check': '头部CT',
#   'infectivity': '肠结核、肺结核',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '神经质、精神病'},
#  '非依赖性物质伴发依赖': {'disease_name': '非依赖性物质伴发依赖',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '猜疑、被害妄想、多疑、烦躁不安、反应迟钝、手机依赖症',
#   'check': '血常规',
#   'infectivity': '周围神经病、肌肉痉挛',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '疑病症'},
#  '性兴奋障碍': {'disease_name': '性兴奋障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,男科,心理咨询科,泌尿外科,内分泌科,神经内科',
#   'symptom': '创伤、性欲减退、抑郁',
#   'check': '血压',
#   'infectivity': '性高潮障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '性欲减退'},
#  '白血病伴发的精神障碍': {'disease_name': '白血病伴发的精神障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,血液内科',
#   'symptom': '头痛、人格改变、精神异常、昏睡、昏迷',
#   'check': '血常规、脑电图(EEG)',
#   'infectivity': '谵妄、恶心和呕吐',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '症状性精神障碍、脑器质性精神障碍'},
#  '白塞病伴发的精神障碍': {'disease_name': '白塞病伴发的精神障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,风湿免疫科',
#   'symptom': '精神异常、幻听、幻觉、痴呆',
#   'check': '心电图、脑电图(EEG)',
#   'infectivity': '失眠、精神衰弱',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '贫血伴发的精神障碍'},
#  '病态人格': {'disease_name': '病态人格',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '攻击行为、无羞惭感、行为无计划性、焦虑性适应障碍',
#   'check': '头部B超、头部MRI',
#   'infectivity': '狂躁症、偏执狂',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '抑郁症'},
#  '反社会人格障碍': {'disease_name': '反社会人格障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '攻击行为、行为无计划性、无羞惭感',
#   'check': '头部B超、头部MRI',
#   'infectivity': '狂躁症、偏执狂',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '抑郁症'},
#  '小儿分离性焦虑症': {'disease_name': '小儿分离性焦虑症',
#   'pathogenic_site': '全身',
#   'department': '儿科,心理咨询科,遗传咨询科,小儿精神科',
#   'symptom': '恶心、腹痛、头痛、胃痛、腹痛伴恶心、呕吐、儿童恐怖症、选择性缄默症',
#   'check': '头部B超、胸部B超',
#   'infectivity': '小儿尿频',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '强迫症'},
#  '谵妄综合征': {'disease_name': '谵妄综合征',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '便秘、痴呆、认知功能障碍、血管性痴呆、药物依赖、药物中毒、意识障碍',
#   'check': '脑脊液检测、头部CT、脑电图(EEG)',
#   'infectivity': '焦虑症、抑郁症、恐怖症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '痴呆综合征'},
#  '功能性聋': {'disease_name': '功能性聋',
#   'pathogenic_site': '头颈部',
#   'department': '心理咨询科,耳鼻喉科',
#   'symptom': '缄默症、四肢震颤、凝视征、听力下降',
#   'check': '耳鼻咽喉CT',
#   'infectivity': '老年痴呆症、忧郁症、语言障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '创伤性耳聋、老年性耳聋'},
#  '身心疾病': {'disease_name': '身心疾病',
#   'pathogenic_site': '全身',
#   'department': '普通外科,精神病科,心理咨询科',
#   'symptom': '心慌、疲乏、抑郁、焦虑',
#   'check': '血常规',
#   'infectivity': '惊厥、脑疝',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '抑郁症、躁狂症'},
#  '乙脑伴发的精神障碍': {'disease_name': '乙脑伴发的精神障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '思维不连贯、流涎、抽搐、动作迟缓、痴呆、情绪不宁、注意力不集中、发热、嗜睡、呕吐、恶心、头痛、健忘、失眠、反应迟钝、口吃、口齿不清、失语、腹痛、腹泻、高热、昏迷、易激惹',
#   'check': '血常规、脑脊液检测、血清补体检测、自身抗体检测',
#   'infectivity': '智力障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、流行性甲型脑炎、意识障碍'},
#  '非器质性性交疼痛': {'disease_name': '非器质性性交疼痛',
#   'pathogenic_site': '腹部',
#   'department': '心理咨询科',
#   'symptom': '心理性性功能障碍',
#   'check': None,
#   'infectivity': '心因性阳萎',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '性交疼痛'},
#  '反应性精神病': {'disease_name': '反应性精神病',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '木僵、被迫害妄想症、哭笑失常、精神创伤、意识模糊、意识朦胧状态、思维控制异常、毫无情感反应、情绪低落、抑郁、自杀行为',
#   'check': '脑电图(EEG)',
#   'infectivity': '抽搐与惊厥',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '精神分裂症、抑郁症、癔症'},
#  '小儿言语和语言障碍': {'disease_name': '小儿言语和语言障碍',
#   'pathogenic_site': '全身',
#   'department': '儿科,心理咨询科,神经内科',
#   'symptom': '口齿不清、说话时字词不能连续、喘息、声音嘶哑、语言发育迟缓、增殖体肥大',
#   'check': '染色体检测',
#   'infectivity': '声带结节',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '儿童孤独症'},
#  '办公室综合症': {'disease_name': '办公室综合症',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '食欲不振、头痛、头晕',
#   'check': '脑电图(EEG)',
#   'infectivity': '心理障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神衰弱'},
#  '小儿学校恐怖症': {'disease_name': '小儿学校恐怖症',
#   'pathogenic_site': '全身',
#   'department': '儿科,心理咨询科,小儿精神科',
#   'symptom': '恐惧、情绪低落、嗜睡、抑郁、儿童退缩行为、幻觉、幻听',
#   'check': '头部B超',
#   'infectivity': '腹痛',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': None},
#  '性病神经症': {'disease_name': '性病神经症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '颤抖、噩梦、耳鸣、感觉过敏、恐惧、尿道内虫咬感或阴道内虫爬感',
#   'check': '血常规、性病病原体检测',
#   'infectivity': '抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '妄想症'},
#  '学生心理问题': {'disease_name': '学生心理问题',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '抑郁',
#   'check': '心理咨询',
#   'infectivity': None,
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '品行障碍'},
#  '急性妄想发作': {'disease_name': '急性妄想发作',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '幻觉、记忆受损、精神异常、恐惧、人格解体、抑郁',
#   'check': '头部CT、心理咨询',
#   'infectivity': '精神分裂症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '应激障碍'},
#  '疾病恐怖': {'disease_name': '疾病恐怖',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '疥疮、麻风恐怖、梅毒恐怖',
#   'check': '心电图、心理咨询',
#   'infectivity': '自闭症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '焦虑症、强迫症'},
#  '广泛性焦虑障碍': {'disease_name': '广泛性焦虑障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '心烦、头痛、坐立不安、惊恐伤肾阳痿、便秘、惊恐反应现象、腹泻、少气、搓手顿足、身体变形障碍、偏执性妄想、闭经、恶心、耳鸣、恐惧',
#   'check': '心理咨询',
#   'infectivity': '强迫症、惊恐障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '精神分裂症、抑郁症'},
#  '格斯特曼综合征': {'disease_name': '格斯特曼综合征',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,神经内科',
#   'symptom': '步态不稳、痴呆、耳聋、肌肉萎缩、肌阵挛、失眠、无力、震颤、智能障碍',
#   'check': '脑电图(EEG)、免疫学检测',
#   'infectivity': '痴呆、耳聋、失明',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '阿尔茨海默病'},
#  '性高潮障碍': {'disease_name': '性高潮障碍',
#   'pathogenic_site': '腹部',
#   'department': '精神病科,心理咨询科',
#   'symptom': '精神异常、心理性性功能障碍',
#   'check': '盆腔及阴道B超',
#   'infectivity': '阴道炎',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '性冷淡'},
#  '急性心因性反应': {'disease_name': '急性心因性反应',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '心理麻木',
#   'check': '心理咨询',
#   'infectivity': '精神障碍、情感障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神病'},
#  '抽动秽语综合征': {'disease_name': '抽动秽语综合征',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,神经内科',
#   'symptom': '不自主运动、喉鸣声、肌阵挛、精神异常、喃喃重复自语',
#   'check': '脑电图(EEG)',
#   'infectivity': '强迫症、情绪障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神障碍'},
#  '系统性红斑狼疮伴发的精神障碍': {'disease_name': '系统性红斑狼疮伴发的精神障碍',
#   'pathogenic_site': '全身',
#   'department': '皮肤科,精神病科,心理咨询科',
#   'symptom': '红斑、记忆受损、失眠、发热',
#   'check': '脑电图(EEG)',
#   'infectivity': '痴呆、精神分裂症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '精神分裂症'},
#  '广场恐惧症': {'disease_name': '广场恐惧症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '紧张、胸闷、心悸',
#   'check': '头部CT',
#   'infectivity': '抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '反社会人格障碍、躁狂症'},
#  '面红和面红恐惧症': {'disease_name': '面红和面红恐惧症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,皮肤科,心理咨询科',
#   'symptom': '腹泻、绝经、恐惧、类癌面红、类癌综合征、皮肤发红、皮肤瘙痒、强迫性神经官能症',
#   'check': '血常规、肝胆功能检查、粪便检测、肌电图',
#   'infectivity': '心律失常',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '心悸'},
#  '惊恐障碍': {'disease_name': '惊恐障碍',
#   'pathogenic_site': '头颈部',
#   'department': '精神病科,心理咨询科',
#   'symptom': '心慌气短',
#   'check': '脑电图(EEG)、心理咨询',
#   'infectivity': '抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '社交恐惧症'},
#  '惊恐症': {'disease_name': '惊恐症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '气短、晕厥、不真实感、胸闷、代脉、无用感',
#   'check': '脑电图(EEG)、心理咨询',
#   'infectivity': '社交恐惧症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '焦虑症、强迫症'},
#  '洁癖': {'disease_name': '洁癖',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '紧张、恐惧、强迫性神经官能症',
#   'check': '心理咨询',
#   'infectivity': '抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '精神病'},
#  '性施虐症与性受虐症': {'disease_name': '性施虐症与性受虐症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '精神变态',
#   'check': '心理咨询',
#   'infectivity': '男科外伤',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '性心理障碍'},
#  '脑神经萎缩型脑瘫': {'disease_name': '脑神经萎缩型脑瘫',
#   'pathogenic_site': '头颈部',
#   'department': '骨科,理疗科 ,康复科,心理咨询科,神经外科,神经内科',
#   'symptom': '智力减低、运动障碍、言语障碍',
#   'check': '头部MRI、头部CT、脑电图(EEG)、神经系统检查',
#   'infectivity': '癫痫、斜视',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '痉挛性截瘫、异染性脑白质营养不良'},
#  '摩擦症': {'disease_name': '摩擦症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '呼吸急促',
#   'check': '脑电图(EEG)、心理咨询',
#   'infectivity': '神经症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '癫痫'},
#  '妄想性障碍': {'disease_name': '妄想性障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科',
#   'symptom': '易于产生病理嫉妒信念、偏执性妄想',
#   'check': None,
#   'infectivity': '精神分裂症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症'},
#  '婚外恋': {'disease_name': '婚外恋',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '恐惧',
#   'check': '心理咨询',
#   'infectivity': None,
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': None},
#  '妄想型精神分裂症': {'disease_name': '妄想型精神分裂症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科',
#   'symptom': '行为及情绪异常、幻听、认知功能障碍、妄想、易激惹',
#   'check': '头部MRI、头部CT',
#   'infectivity': '紧张型精神分裂症、精神分裂症、精神衰弱、儿童精神分裂症、意志缺乏症、早期精神分裂症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '妄想性障碍'},
#  '遗忘综合征': {'disease_name': '遗忘综合征',
#   'pathogenic_site': '头颈部',
#   'department': '心理咨询科',
#   'symptom': '定向力障碍、一过性全面性遗忘、分离性漫游症、轴性遗忘症、后发性遗忘',
#   'check': '头部CT',
#   'infectivity': '睡眠障碍、意识障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '脑震荡'},
#  '家庭心理问题': {'disease_name': '家庭心理问题',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '心理伤害',
#   'check': '心理咨询',
#   'infectivity': None,
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': None},
#  '臭汗恐惧症': {'disease_name': '臭汗恐惧症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '紧张、恐惧、自觉汗臭',
#   'check': '心理咨询',
#   'infectivity': '精神障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '恐惧症'},
#  '冲动控制障碍': {'disease_name': '冲动控制障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '冲动型人格障碍、精神异常',
#   'check': '心理咨询',
#   'infectivity': '精神障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '冲动型人格障碍'},
#  '农药中毒所致的精神障碍': {'disease_name': '农药中毒所致的精神障碍',
#   'pathogenic_site': '全身',
#   'department': '急诊科,心理咨询科,神经内科',
#   'symptom': '多梦、恶心、耳聋、腹泻、感觉障碍',
#   'check': '心电图、脑电图(EEG)',
#   'infectivity': '脑水肿',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神病'},
#  '考后综合症': {'disease_name': '考后综合症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '暴饮暴食、紧张、强迫行为、抑郁、烦躁不安、精神异常',
#   'check': '头部MRI、头部CT、心电图、心理咨询',
#   'infectivity': '失眠、肥胖症、肠胃炎、自闭症',
#   'heredity': '该病具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症'},
#  '酒精戒断综合征': {'disease_name': '酒精戒断综合征',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,成瘾医学科',
#   'symptom': '发热、眼睑痉挛、失眠、头痛、全身多汗、戒断性痫性发作、心慌、酒精成瘾、类戒断反应',
#   'check': '脑电图(EEG)',
#   'infectivity': '幻觉、酒精性谵妄',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '戒断综合征'},
#  '急性应激反应': {'disease_name': '急性应激反应',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '埃斯博格综合征、运动性兴奋或抑制、精神异常、精神过敏、术后急性精神障碍、精神创伤、情绪低落、定向力障碍、意识障碍',
#   'check': '心电图、胃镜',
#   'infectivity': '失眠、恶劣心境',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '癔症、情感性心境障碍'},
#  '进食障碍': {'disease_name': '进食障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '消瘦、粪便量少、营养不良',
#   'check': None,
#   'infectivity': '营养不良',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、抑郁症、强迫症'},
#  '拔毛狂': {'disease_name': '拔毛狂',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '风热挟毒头白秃、脱发、头白秃、腹痛、厌食、体毛脱落、便秘、断毛癖、斑秃',
#   'check': '头部B超、心理咨询',
#   'infectivity': '肠梗阻、抑郁症',
#   'heredity': '该病具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '偏执狂'},
#  '小儿精神发育迟缓': {'disease_name': '小儿精神发育迟缓',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,小儿精神科,小儿神经内科',
#   'symptom': '儿童行为孤僻、反应迟钝、嗜睡、心理年龄小于生理年龄、语言发育迟缓',
#   'check': '脑电图(EEG)',
#   'infectivity': '生长发育迟缓',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '儿童精神分裂症'},
#  '小儿孤独症': {'disease_name': '小儿孤独症',
#   'pathogenic_site': '全身',
#   'department': '儿科,心理咨询科,小儿神经内科',
#   'symptom': '社交敏感性障碍、智能障碍、空间感知障碍、口吃、拒食、睡眠障碍',
#   'check': '脑血管造影',
#   'infectivity': '小儿癫痫',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '精神分裂症'},
#  '绝经与抑郁症': {'disease_name': '绝经与抑郁症',
#   'pathogenic_site': '全身',
#   'department': '妇科,心理咨询科,内分泌科',
#   'symptom': '便秘、恶心、腹胀、幻觉、精神异常、绝经、绝望感、皮肤瘙痒',
#   'check': '性腺激素检测',
#   'infectivity': '内分泌疾病',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症'},
#  '性障碍': {'disease_name': '性障碍',
#   'pathogenic_site': '全身',
#   'department': '妇科,男科,心理咨询科,中医外科',
#   'symptom': '易性别癖、露阴癖、异装癖、性交疼痛、快感缺乏、性欲减退',
#   'check': '阴囊及阴茎B超',
#   'infectivity': '焦虑症、抑郁症、心理障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '早泄、阳痿'},
#  '致死性家族性失眠症': {'disease_name': '致死性家族性失眠症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,神经内科',
#   'symptom': '多梦、幻觉、昏睡、肌阵挛、口齿不清、木僵',
#   'check': '头部CT',
#   'infectivity': '神经衰弱',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '产后失眠'},
#  '恐缩症': {'disease_name': '恐缩症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科,特色医疗科',
#   'symptom': '烦躁不安、幻觉、惊恐发作、面色苍白、尿急、心慌、眩晕',
#   'check': '头部CT、心理咨询',
#   'infectivity': '神经衰弱',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '颅脑损伤'},
#  '言语和语言发育障碍': {'disease_name': '言语和语言发育障碍',
#   'pathogenic_site': '头颈部',
#   'department': '儿科,心理咨询科,产前诊断科,遗传咨询科,神经内科,小儿神经内科',
#   'symptom': '行为紊乱而奇特、语言发育迟缓、焦虑、情绪障碍、注意力不集中、发音改变、颤抖、发音障碍、恐惧、口吃',
#   'check': '头部CT',
#   'infectivity': '抑郁症、自闭症、精神病、孤独症、意识障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '口吃'},
#  '窥阴癖': {'disease_name': '窥阴癖',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,中医内科',
#   'symptom': '紧张、紧张性手抖、窥淫癖',
#   'check': '心理咨询',
#   'infectivity': '社交恐惧症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '窥阴癖'},
#  '空巢综合症': {'disease_name': '空巢综合症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '精神萎靡',
#   'check': '心电图、心理咨询',
#   'infectivity': '老年痴呆症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '抑郁症'},
#  '应激反应及适应障碍': {'disease_name': '应激反应及适应障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '创伤、功能性头痛、紧张、丧偶后适应性障碍、应激功能减退',
#   'check': '头部CT',
#   'infectivity': '胃溃疡、神经性头痛',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '创伤后应激障碍'},
#  '延迟性应激反应': {'disease_name': '延迟性应激反应',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '创伤、快感缺乏、失眠、抑郁',
#   'check': '血常规、心电图',
#   'infectivity': '精神分裂症、抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '应激障碍'},
#  '恋物症': {'disease_name': '恋物症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '迷恋足部或鞋袜、恋毛巾被癖',
#   'check': '头部MRI、头部CT、心理咨询',
#   'infectivity': '抑郁倾向',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '易性症、异装症'},
#  '呼吸系统疾病伴发的精神障碍': {'disease_name': '呼吸系统疾病伴发的精神障碍',
#   'pathogenic_site': '胸部',
#   'department': '呼吸内科,精神病科,心理咨询科,中医内科,神经内科',
#   'symptom': '兴奋躁动、言语错乱、谵妄、昏睡、烦躁、嗜睡、意识障碍、近事遗忘现象、言语增多、木僵、抽搐、意识丧失、意识模糊、幻听、猜疑、被害妄想、眼球运动障碍、肌阵挛、扑翼样震颤、妄想、恐惧、情绪障碍、抑郁、焦虑',
#   'check': '胸部MRI、胸部CT、脑电图(EEG)、X线平片、痰液检测、支气管镜、血液检查、放射性核素检查、活体组织病理检查（活检）',
#   'infectivity': '肝衰竭、颅内压增高、脑水肿、上消化道出血、消化系统疾病、休克、心律失常、电解质紊乱、内脏损伤',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '非器质性精神病、精神分裂症、器质性精神障碍'},
#  '失恋': {'disease_name': '失恋',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '猜疑、喜怒无常、绝望感',
#   'check': '心理咨询',
#   'infectivity': '抑郁症、狂躁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '恋爱困惑'},
#  '失眠抑郁': {'disease_name': '失眠抑郁',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,神经内科',
#   'symptom': '周身不适、黑眼圈、头痛、头晕',
#   'check': '脑电图(EEG)',
#   'infectivity': '高血压、冠心病',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '自闭症'},
#  '延迟性心因性反应': {'disease_name': '延迟性心因性反应',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,产前诊断科,遗传咨询科',
#   'symptom': '情感麻痹、心慌、失眠、气短',
#   'check': '血常规',
#   'infectivity': '反应性精神病、精神病',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '抑郁症'},
#  '学习技能发育障碍': {'disease_name': '学习技能发育障碍',
#   'pathogenic_site': '头颈部',
#   'department': '精神病科,心理咨询科',
#   'symptom': '大脑发育障碍、精神异常、品行障碍、认知功能障碍、失读、听觉障碍、智能障碍、注意力不集中',
#   'check': '头部CT、脑电图(EEG)、神经系统检查',
#   'infectivity': '小儿言语和语言障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '儿童孤独症、儿童精神分裂症'},
#  '性身份障碍': {'disease_name': '性身份障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,神经内科',
#   'symptom': '男性化',
#   'check': '神经系统检查、心理咨询',
#   'infectivity': '双性恋',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '双重异装症、易性症'},
#  '注意缺陷障碍': {'disease_name': '注意缺陷障碍',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,小儿营养保健科',
#   'symptom': '注意力不集中、注意力缺乏多动症、易激惹、品行障碍',
#   'check': '头部CT',
#   'infectivity': '活动与注意力失调',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '小儿多动症'},
#  '脏躁': {'disease_name': '脏躁',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '抑郁、烦躁不安、易哭、喜怒无常',
#   'check': '头部CT、中医诊断',
#   'infectivity': '产后抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '躁狂症'},
#  '脑垂体功能异常伴发的精神障碍': {'disease_name': '脑垂体功能异常伴发的精神障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,内分泌科,神经内科',
#   'symptom': '白天嗜睡夜间失眠、伴有生动鲜明的恐怖性幻视、被害妄想、痴呆、呆滞、低血压、恶心',
#   'check': '头部CT、脑电图(EEG)、垂体激素检测',
#   'infectivity': '癫痫',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、抑郁症、癔症'},
#  '阴道痉挛': {'disease_name': '阴道痉挛',
#   'pathogenic_site': '腹部',
#   'department': '妇科,心理咨询科',
#   'symptom': '肝郁气滞阴痛、阴痛、心理性性功能障碍、下腹坠胀、性交困难、性交疼痛、子宫内膜异位',
#   'check': '心理咨询',
#   'infectivity': '抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '非器质性性交疼痛'},
#  '言语障碍': {'disease_name': '言语障碍',
#   'pathogenic_site': '头颈部',
#   'department': '心理咨询科,神经内科,小儿神经内科',
#   'symptom': '婴儿说话晚、重音现象、舌肌麻痹、舌肌萎缩、吟诗样语言、运动性失语',
#   'check': '头部CT',
#   'infectivity': '孤独症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '发育迟缓'},
#  '癔症性失声': {'disease_name': '癔症性失声',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '失语、抑郁、失音',
#   'check': '心理咨询',
#   'infectivity': '抑郁倾向',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '感觉性失语'},
#  '异装症': {'disease_name': '异装症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '性心理不成熟、精神变态',
#   'check': '染色体检测',
#   'infectivity': '精神分裂症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '双性恋'},
#  '癔病性昏厥': {'disease_name': '癔病性昏厥',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,神经内科',
#   'symptom': '一过性昏厥、忧郁',
#   'check': '心电图',
#   'infectivity': '躯体感觉障碍',
#   'heredity': '该病具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '昏厥'},
#  '郁证': {'disease_name': '郁证',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,中医内科',
#   'symptom': '恐惧、情志内伤、易哭、忧郁、脘痞',
#   'check': '血常规、CT',
#   'infectivity': '精神衰弱、失眠多梦',
#   'heredity': '该病具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '抑郁症'},
#  '恐惧症': {'disease_name': '恐惧症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科,小儿精神科',
#   'symptom': '社交恐惧、场所恐惧',
#   'check': '心理咨询',
#   'infectivity': '焦虑症、疑病症、强迫症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '复发性抑郁障碍、焦虑症、疑病症、强迫症、颞叶癫痫'},
#  '感应性妄想性障碍': {'disease_name': '感应性妄想性障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '幻听、精神异常',
#   'check': '心理咨询',
#   'infectivity': '幻听、妄想症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '精神分裂症、癔症'},
#  '适应障碍': {'disease_name': '适应障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '失眠、行为及情绪异常、食欲不振、对生活丧失兴趣、沮丧、绝望感、品行障碍、头痛、焦虑',
#   'check': '头部MRI、头部CT、脑电图(EEG)、心理咨询',
#   'infectivity': '失眠、焦虑症、抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '边缘型人格障碍、表演型人格障碍、大脑功能障碍、焦虑障碍'},
#  '偏执狂': {'disease_name': '偏执狂',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '妄想、自恋',
#   'check': '心理咨询',
#   'infectivity': '躁狂状态、抑郁倾向',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '偏执状态'},
#  '偏执状态': {'disease_name': '偏执状态',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '诉讼狂、被害妄想',
#   'check': '心理咨询、血液检查',
#   'infectivity': '抑郁倾向',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '器质性精神障碍、偏执狂、情感障碍'},
#  '急性短暂性精神障碍': {'disease_name': '急性短暂性精神障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '情绪障碍、定向力障碍',
#   'check': '心理咨询',
#   'infectivity': '幻觉、妄想症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': None},
#  '寄生虫妄想': {'disease_name': '寄生虫妄想',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '溃疡、瘙痒、蚁走感',
#   'check': '心理咨询',
#   'infectivity': '溃疡',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症'},
#  '窥阴症': {'disease_name': '窥阴症',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '以偷窥为快感源泉的性变态',
#   'check': '心理咨询',
#   'infectivity': '社交恐惧症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '窥淫症'},
#  '应激障碍': {'disease_name': '应激障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '运动性兴奋或抑制、心理麻木、情感麻痹',
#   'check': '脑电图(EEG)',
#   'infectivity': '溃疡、感染',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '延迟性应激反应、应激反应及适应障碍'},
#  '厌学': {'disease_name': '厌学',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,小儿精神科',
#   'symptom': '精神异常、学习障碍',
#   'check': '心理咨询',
#   'infectivity': '失眠、耳鸣、腹泻、焦虑症、抑郁症、头晕、记忆障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、焦虑症、抑郁症'},
#  '产后失眠': {'disease_name': '产后失眠',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,产科',
#   'symptom': '抑郁、失眠',
#   'check': '中医诊断',
#   'infectivity': '神经衰弱、感冒',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '抑郁症'}}

# %%
json_dic
# Out:
# {'早恋': {'disease_name': '早恋',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '性早熟',
#   'check': '心理咨询',
#   'infectivity': '早孕',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神障碍'},
#  '产后抑郁症': {'disease_name': '产后抑郁症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '抑郁症、愉快感缺乏、失眠、单次发作抑郁症、沮丧、思维紊乱、产后肥胖、思考困难感、产后抑郁症、决断困难感、抑郁性木僵、进食异常、不真实感、川字纹',
#   'check': '头部B超、头部MRI、脑电图(EEG)',
#   'infectivity': '失眠、焦虑障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '焦虑症'},
#  '癔症': {'disease_name': '癔症',
#   'pathogenic_site': '全身',
#   'department': '中医内科',
#   'symptom': '紫绀、关节肿痛',
#   'check': '中医诊断',
#   'infectivity': '心悸、神昏',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '瘀斑、血瘀'},
#  '幻觉': {'disease_name': '幻觉',
#   'pathogenic_site': '头颈部',
#   'department': '精神病科,心理咨询科',
#   'symptom': '易激动、幻觉、入睡幻觉、梦幻觉',
#   'check': '头部B超、头部MRI、脑电图(EEG)',
#   'infectivity': '精神分裂症、癔症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '癫痫、酒精中毒、精神分裂症'},
#  '意志缺乏症': {'disease_name': '意志缺乏症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '谵妄、嗜睡、情感淡漠、思维贫乏',
#   'check': None,
#   'infectivity': None,
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '闭锁综合征、木僵、抑郁症'},
#  '口吃': {'disease_name': '口吃',
#   'pathogenic_site': '头颈部',
#   'department': '心理咨询科,神经内科',
#   'symptom': '讷吃、言语表达障碍、口齿不清、口吃、语言发育迟缓、构音困难现象',
#   'check': '头部B超、头部MRI、头部CT',
#   'infectivity': '功能性遗尿、睡眠障碍、心因性无食欲',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '言语障碍'},
#  '露阴症': {'disease_name': '露阴症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '露阴癖、精神变态',
#   'check': '心理咨询',
#   'infectivity': '抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '恋物癖'},
#  '强迫性障碍': {'disease_name': '强迫性障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '强迫行为、强迫观念、强迫性性行为、强迫性联想、强迫型人格障碍',
#   'check': '头部MRI、头部CT',
#   'infectivity': '失眠、营养不良、抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、社交恐惧症、抑郁症'},
#  '轻度抑郁发作': {'disease_name': '轻度抑郁发作',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '抑郁症、无用感、忧郁思虑、食欲减退、思考困难感',
#   'check': '脑电图(EEG)',
#   'infectivity': '失眠、食欲缺乏、头痛',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '焦虑症、神经衰弱'},
#  '人格障碍': {'disease_name': '人格障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '抑郁、心境高涨、猜疑、善怒',
#   'check': '头部MRI、头部CT、脑电图(EEG)',
#   'infectivity': '抑郁症、狂躁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '偏执性精神障碍'},
#  '神经性厌食': {'disease_name': '神经性厌食',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,消化内科',
#   'symptom': '食欲减退、夏季厌食、消瘦、营养不良、餐后即刻呕吐、进食异常、夏季厌食症、毛发呈脱发样、外源性消瘦、食欲异常',
#   'check': '血常规、头部CT、脑电图(EEG)',
#   'infectivity': '闭经、低血压、发育障碍、营养性消瘦',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、脑肿瘤、抑郁症、原发性小肠吸收不良综合征'},
#  '神经衰弱': {'disease_name': '神经衰弱',
#   'pathogenic_site': '头颈部',
#   'department': '心理咨询科,中医内科,神经内科',
#   'symptom': '注意力不集中、睡眠障碍、易激惹、头晕、疲乏',
#   'check': '头部CT、心电图、脑电图(EEG)',
#   'infectivity': '焦虑症、抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '动脉硬化性脑病、精神分裂症、焦虑症、颅内占位性病变、颅内感染、抑郁症、慢性疲劳综合症'},
#  '社交恐惧症': {'disease_name': '社交恐惧症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,神经内科',
#   'symptom': '恐惧、坐立不安、善忧思、脸红、善恐、善惊、疥疮恐惧、社交恐惧、体象障碍、产后抑郁症、晕血、轻度失眠',
#   'check': '头部CT、脑电图(EEG)',
#   'infectivity': '头痛、心悸',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '惊恐障碍[间歇发作性焦虑]'},
#  '神经质': {'disease_name': '神经质',
#   'pathogenic_site': '头颈部',
#   'department': '精神病科,心理咨询科',
#   'symptom': '无能力感、头摇、赔偿性神经症、感觉过度、舌震颤、紧张、行为及情绪异常、神经质性格、厌食、精神过敏、信息成瘾、间歇性耳聋、感觉倒错、癔症步态、烦躁不安、失眠、灾难反应、易醒、意向倒错、夸大狂、燥狂相、喜讲秽语、心境高涨、痛阈降低、听觉过敏、食欲异常、性受虐癖、疑病症、轻度失眠',
#   'check': '头部MRI、头部CT、脑电图(EEG)',
#   'infectivity': '便秘、失眠、抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '周围神经病、精神病'},
#  '贪食': {'disease_name': '贪食',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,消化内科',
#   'symptom': '食积痛、贪食症、便下恶臭、体重增加、贪食行为、多食、放屁过臭、婴儿过胖、易饿、中度肥胖、食欲异常',
#   'check': '血常规、头部MRI',
#   'infectivity': '肥胖症、抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '甲状腺机能亢进症'},
#  '性交疼痛': {'disease_name': '性交疼痛',
#   'pathogenic_site': '腹部',
#   'department': '妇科,心理咨询科,泌尿外科',
#   'symptom': '性交困难、刺痛、外阴烧灼刺激感、性交疼痛、钝痛',
#   'check': '前列腺及精囊腺B超、盆腔及阴道B超、阴道镜、阴道分泌物检测',
#   'infectivity': '性高潮功能障碍、勃起功能障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '尿路感染、阴道痉挛'},
#  '抑郁症': {'disease_name': '抑郁症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科',
#   'symptom': '沮丧、精神萎靡、呆滞、思维缓慢、情感淡漠、情绪低落',
#   'check': '脑脊液检测、头部MRI、脑电图(EEG)',
#   'infectivity': '便秘、焦虑症、睡眠障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、偏执型精神分裂症、心理障碍'},
#  '疑病症': {'disease_name': '疑病症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '恶心、呼吸困难、胸痛、心悸、腹泻、疼痛',
#   'check': None,
#   'infectivity': '焦虑症、抑郁症、强迫症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、神经衰弱、躁狂状态'},
#  '厌食症 ': {'disease_name': '厌食症 ',
#   'pathogenic_site': '全身',
#   'department': '营养科,心理咨询科,神经内科',
#   'symptom': '食欲异常、营养不良、消瘦',
#   'check': '头部MRI、头部CT、脑电图(EEG)',
#   'infectivity': '低血压、贫血、生长发育迟缓、营养不良',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、脑肿瘤、消化不良、抑郁症'},
#  '强迫症': {'disease_name': '强迫症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '强迫观念、强迫性重复、强迫行为',
#   'check': '血常规、脑电图(EEG)',
#   'infectivity': '抽动障碍、焦虑症、人格障碍、精神病',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、抑郁症'},
#  '歇斯底里': {'disease_name': '歇斯底里',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '言语错乱、意识障碍、感觉过敏、自杀行为、运动障碍',
#   'check': '血常规、头部CT、脑电图(EEG)',
#   'infectivity': '焦虑症、人格障碍、神经衰弱、抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '反应性精神病、精神分裂症'},
#  '忧郁症': {'disease_name': '忧郁症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '忧郁、阳气郁伏、发作后精神障碍、情感淡漠、忧郁思虑、胸闷长叹息气短、喜叹息、思维缓慢、被窃或疑病妄想、决断困难感、听觉过敏、信息成瘾',
#   'check': '脑脊液检测、头部MRI、脑电图(EEG)',
#   'infectivity': '焦虑症、睡眠障碍、心悸、性欲减退',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、器质性精神障碍'},
#  '心理障碍': {'disease_name': '心理障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医精神科',
#   'symptom': '品行障碍、智力减低、抑郁、妄想、幻觉、焦虑',
#   'check': '头部CT、脑电图(EEG)、心理咨询',
#   'infectivity': '幻听、幻视、妄想狂',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '个人心理成长'},
#  '重度抑郁症': {'disease_name': '重度抑郁症',
#   'pathogenic_site': '头颈部',
#   'department': '心理咨询科,神经内科',
#   'symptom': '抑郁症、反复发作抑郁症、愉快感缺乏、忧郁思虑、思维缓慢、失眠、情感淡漠、思考困难感、决断困难感、抑郁性木僵、不真实感',
#   'check': '血常规、头部MRI、脑电图(EEG)',
#   'infectivity': '睡眠障碍、性欲减退',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、神经官能症'},
#  '躁郁症': {'disease_name': '躁郁症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '心烦、言语增多、运动性兴奋或抑郁、运动障碍疾病、心境高涨、躁郁样、烦躁不安、抑郁、喜怒无常',
#   'check': '头部MRI、头部CT、脑电图(EEG)',
#   'infectivity': '精神分裂症、躁狂状态',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '神经衰弱、抑郁症、躁狂状态'},
#  '自闭症': {'disease_name': '自闭症',
#   'pathogenic_site': '全身',
#   'department': '儿科,精神病科,心理咨询科,小儿精神科',
#   'symptom': '节律性刻板重复的不自主运动、对生活丧失兴趣、社交恐惧',
#   'check': '头部CT、脑电图(EEG)',
#   'infectivity': '癫痫、智力低下、儿童攻击行为',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '阿斯伯格综合症、儿童精神分裂症、小儿精神发育迟缓'},
#  '纤维肌痛综合症': {'disease_name': '纤维肌痛综合症',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,中医内科,神经内科',
#   'symptom': '肌肉压痛、睡眠障碍、肌肤疼痛、晨僵、疲乏',
#   'check': '血常规、脑脊液检测',
#   'infectivity': '焦虑症、头痛、抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '风湿性多肌痛、类风湿关节炎、慢性疲劳综合征'},
#  '恋物癖': {'disease_name': '恋物癖',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,成瘾医学科',
#   'symptom': '迷恋足部或鞋袜',
#   'check': None,
#   'infectivity': '早泄、窥阴癖、露阴癖',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '恋物性异装症、易性症、性变态'},
#  '创伤后应激障碍': {'disease_name': '创伤后应激障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '噩梦、惊跳、恐惧、面色苍白、气短',
#   'check': '心理咨询',
#   'infectivity': '抑郁症、延迟性应激反应',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神障碍'},
#  '癫狂病': {'disease_name': '癫狂病',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科',
#   'symptom': '情感高涨、情绪低落、睡眠障碍',
#   'check': '血常规、头部MRI、头部CT、脑电图(EEG)、心理咨询',
#   'infectivity': '睡眠障碍、心脏病',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '癫病、狂病、脏躁'},
#  '儿童精神分裂症': {'disease_name': '儿童精神分裂症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科,小儿精神科',
#   'symptom': '睡眠障碍、注意力不集中、儿童行为孤僻、紧张、伴有生动鲜明的恐怖性幻视、口齿含糊、被害妄想',
#   'check': '头部MRI、头部CT、脑电图(EEG)',
#   'infectivity': '精神衰弱',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '童年社交焦虑障碍、小儿多动症、儿童情绪障碍、儿童孤独症、小儿精神发育迟缓'},
#  '忽略症': {'disease_name': '忽略症',
#   'pathogenic_site': '头颈部',
#   'department': '精神病科,心理咨询科',
#   'symptom': '偏侧不注意、垂直性忽略症、感觉障碍、偏侧空间忽略症、偏盲、运动性忽略症',
#   'check': '头部CT',
#   'infectivity': '肺部感染、尿路感染、偏执狂',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '颅内肿瘤'},
#  '非器质性阴道痉挛': {'disease_name': '非器质性阴道痉挛',
#   'pathogenic_site': '腹部',
#   'department': '心理咨询科',
#   'symptom': '肝郁气滞阴痛、阴道闭锁',
#   'check': '肌电图',
#   'infectivity': '阴道闭锁',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '性交疼痛'},
#  '睡眠障碍': {'disease_name': '睡眠障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,神经内科',
#   'symptom': '缺乏深睡眠、睡眠不足、夜寐不实、白天嗜睡夜间失眠、白天睡眠过度',
#   'check': '头部MRI、心电图、脑电图(EEG)、血液检查、CT、神经心理学测验',
#   'infectivity': '精神衰弱',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '失眠'},
#  '遗尿症': {'disease_name': '遗尿症',
#   'pathogenic_site': '腹部',
#   'department': '心理咨询科,肾内科',
#   'symptom': '排尿困难、尿频、尿急、尿流变细或中断',
#   'check': '尿液检测、肾脏及输尿管B超、脑电图(EEG)、X线平片、血液检查',
#   'infectivity': '精神分裂症、发育迟缓',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '尿失禁'},
#  '恐怖性焦虑障碍': {'disease_name': '恐怖性焦虑障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '惊恐反应现象、儿童恐怖症、坐立不安、善恐、场所恐惧、麻风恐怖、惊恐发作、晕血、步态不稳、颤抖、呼吸困难、焦虑性适应障碍、紧张',
#   'check': '心理咨询',
#   'infectivity': '社交恐怖、抑郁倾向',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '焦虑症'},
#  '狂病': {'disease_name': '狂病',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科',
#   'symptom': '精神异常、哭笑失常、谵妄、行为及情绪异常、秋季狂躁症、技术狂躁症',
#   'check': '脑电图(EEG)、中医诊断',
#   'infectivity': '癫痫',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症'},
#  '情感性心境障碍': {'disease_name': '情感性心境障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科',
#   'symptom': '情感高涨、抑郁、思维缓慢、情绪低落、易激动',
#   'check': '血常规',
#   'infectivity': '痴呆',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '痴呆、精神分裂症、神经衰弱'},
#  '小儿多动症': {'disease_name': '小儿多动症',
#   'pathogenic_site': '头颈部',
#   'department': '心理咨询科,小儿精神科,小儿神经内科',
#   'symptom': '不断眨眼、单侧及假性手足徐动、腹壁不自主轴动、情绪不宁、新生儿手足徐动、注意力不集中',
#   'check': '神经系统检查',
#   'infectivity': '情感障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '发育障碍、精神障碍、精神发育迟缓'},
#  '女性性高潮障碍': {'disease_name': '女性性高潮障碍',
#   'pathogenic_site': '腹部',
#   'department': '妇科,心理咨询科',
#   'symptom': '充血、四肢肌张力增强、阴道分泌物增多',
#   'check': '性腺激素检测、心理咨询',
#   'infectivity': '性欲缺失',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '性功能障碍'},
#  '偏执性精神障碍': {'disease_name': '偏执性精神障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '被害妄想、抑郁、疑病症、妄想',
#   'check': None,
#   'infectivity': '强迫症、妄想症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、偏执型人格障碍'},
#  '儿童分离性焦虑障碍': {'disease_name': '儿童分离性焦虑障碍',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,小儿精神科',
#   'symptom': '脾气变坏、恶心、头痛、烦躁不安',
#   'check': '神经系统检查',
#   'infectivity': '恐惧症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '广泛性焦虑障碍、儿童恐惧症、小儿学校恐怖症'},
#  '气功性精神障碍': {'disease_name': '气功性精神障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科',
#   'symptom': '四肢麻木、腹痛、腹胀、头晕、头痛',
#   'check': '神经心理学测验',
#   'infectivity': '精神障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、癔症'},
#  '神经症': {'disease_name': '神经症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,神经内科',
#   'symptom': '脾气变坏、对生活丧失兴趣、儿童恐怖症、呼吸困难、紧张、恐惧',
#   'check': '神经系统检查',
#   'infectivity': '便秘、遗精',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '反应性精神病、感染性精神病'},
#  '童年情绪障碍': {'disease_name': '童年情绪障碍',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,小儿精神科',
#   'symptom': '恶心、噩梦、烦躁不安、腹痛、攻击行为',
#   'check': '心理咨询',
#   'infectivity': '抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '情绪不稳型人格障碍'},
#  '童年社会功能障碍': {'disease_name': '童年社会功能障碍',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,小儿精神科',
#   'symptom': '缄默症、精神异常、恐惧、抑郁、易激惹',
#   'check': '心理咨询',
#   'infectivity': '焦虑症、抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '社会化品行障碍'},
#  '网络成瘾': {'disease_name': '网络成瘾',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,成瘾医学科',
#   'symptom': '思维缓慢、情绪低落、睡眠障碍',
#   'check': None,
#   'infectivity': '精神损伤',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '心理障碍'},
#  '女子梦交': {'disease_name': '女子梦交',
#   'pathogenic_site': '头颈部',
#   'department': '精神病科,心理咨询科,中医内科,神经内科',
#   'symptom': '精神过敏、头痛、头晕、喜怒无常',
#   'check': '头部CT、神经系统检查、心理咨询',
#   'infectivity': '精神分裂症、颅咽管瘤、副鼻窦炎、脑动静脉畸形',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': None},
#  '性厌恶': {'disease_name': '性厌恶',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '恐惧、性交困难、性欲减退',
#   'check': '血常规',
#   'infectivity': '心理障碍、不孕不育症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '性功能障碍'},
#  '恐怖症': {'disease_name': '恐怖症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '恐惧、紧张、社交恐惧',
#   'check': None,
#   'infectivity': '情绪障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '精神分裂症、焦虑症、疑病症、强迫症'},
#  '梦魇': {'disease_name': '梦魇',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '疲劳、出冷汗、面色苍白',
#   'check': None,
#   'infectivity': '呼吸困难、疲劳综合征、消化不良',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '惊厥、惊恐症、夜惊'},
#  '性心理障碍': {'disease_name': '性心理障碍',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '露阴癖、性施虐癖、性受虐癖',
#   'check': None,
#   'infectivity': '婚恋心理问题',
#   'heredity': '该病具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '恋物症、人格障碍、易性症'},
#  '心理应激': {'disease_name': '心理应激',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '睡眠障碍、食欲减退、情绪不宁、注意力不集中、惊跳',
#   'check': None,
#   'infectivity': '高血压、冠心病、心律失常、应激性溃疡',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '癔症、创伤后应激障碍、分裂情感性障碍'},
#  '心身疾病': {'disease_name': '心身疾病',
#   'pathogenic_site': '全身',
#   'department': '普通外科,精神病科,心理咨询科,中医内科',
#   'symptom': '心理伤害',
#   'check': '甲状腺及甲状旁腺B超、心理咨询',
#   'infectivity': '精神障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': None},
#  '性变态': {'disease_name': '性变态',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '易性别癖、性受虐癖、性施虐癖、性窒息、异装癖、窥淫癖、露阴癖',
#   'check': '心电图',
#   'infectivity': '早泄、阳痿、恐惧症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '人格障碍、性偏好障碍、心理障碍'},
#  '性冷淡': {'disease_name': '性冷淡',
#   'pathogenic_site': '臀部',
#   'department': '妇科,男科,心理咨询科',
#   'symptom': '性交疼痛、阴道干涩、快感缺乏、恐惧',
#   'check': None,
#   'infectivity': '性功能障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '性欲减退、早泄、阳痿'},
#  '小儿厌食症': {'disease_name': '小儿厌食症',
#   'pathogenic_site': '腹部',
#   'department': '心理咨询科,消化内科,小儿消化科,小儿营养保健科',
#   'symptom': '便血、低热、反应迟钝、骨软化、精神萎靡、拒食、溃疡',
#   'check': '胃镜',
#   'infectivity': '发育障碍、营养不良',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '缺铁性贫血、寄生虫病'},
#  '幻肢疼痛': {'disease_name': '幻肢疼痛',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,针灸按摩科,神经内科',
#   'symptom': None,
#   'check': '神经系统检查、心理咨询',
#   'infectivity': None,
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '躯体感觉障碍'},
#  '躯体感觉障碍': {'disease_name': '躯体感觉障碍',
#   'pathogenic_site': '全身',
#   'department': '康复科,心理咨询科,神经内科',
#   'symptom': '放射性疼痛、感觉障碍、对侧躯体痛温觉减退或缺失、对侧上肢或下肢感觉缺失',
#   'check': '脑脊液检测、头部B超、头部MRI、头部CT、心电图、X线平片',
#   'infectivity': '脊髓空洞症、多发性神经病、髓内肿瘤',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '小儿格林巴利综合症、椎管内神经鞘瘤'},
#  '儿童恐惧症': {'disease_name': '儿童恐惧症',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,小儿精神科,小儿神经内科',
#   'symptom': '呼吸急促、恐惧、心慌',
#   'check': '神经系统检查、心理咨询',
#   'infectivity': '焦虑症、疑病症、强迫症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '焦虑症、疑病症、儿童强迫症、儿童精神分裂症、颞叶癫痫'},
#  '品行障碍': {'disease_name': '品行障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '暴怒、猥亵行为、抑郁、易激惹、病理性偷窃',
#   'check': '心理咨询',
#   'infectivity': None,
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、心境障碍、小儿多动症、精神发育迟滞、脑器质性精神障碍'},
#  '儿童口吃': {'disease_name': '儿童口吃',
#   'pathogenic_site': '头颈部',
#   'department': '心理咨询科,小儿精神科,小儿神经内科',
#   'symptom': '情绪障碍、言语表达障碍',
#   'check': '神经系统检查、心理咨询',
#   'infectivity': '神经质、儿童睡眠障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': None},
#  '婚恋心理问题': {'disease_name': '婚恋心理问题',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '情绪不宁、思维奔逸、幻觉、抑郁、易激动',
#   'check': '神经系统检查、心理咨询',
#   'infectivity': '抑郁症',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '反应性精神病、精神分裂症、神经衰弱、精神病'},
#  '烟酒依赖症': {'disease_name': '烟酒依赖症',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,中医内科,成瘾医学科',
#   'symptom': '注意力不集中、善怒、焦虑、烦躁不安、失眠、震颤、不可克制的饮酒',
#   'check': '心理咨询',
#   'infectivity': '白血病、肺炎、高血压、肝功能不全、贫血、器质性阳萎、哮喘、消化性溃疡、营养不良、牙周病、周围血管病、主动脉瘤、中风、癌症、血栓闭塞性脉管炎',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '酒精中毒、毒瘾'},
#  '儿童期情绪障碍': {'disease_name': '儿童期情绪障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科,小儿精神科',
#   'symptom': '对生活丧失兴趣、情感暴发、恐惧、儿童退缩行为、强迫行为、意识朦胧状态、情绪低落',
#   'check': '神经系统检查、心理咨询',
#   'infectivity': '人格障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '双相性情感障碍、小儿多动症、儿童精神分裂症、小儿精神发育迟缓'},
#  '围术期伴发的精神障碍': {'disease_name': '围术期伴发的精神障碍',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '猜疑、反应迟钝、幻觉、紧张、精神异常、沮丧、恐惧',
#   'check': '脑脊液检测、头部CT',
#   'infectivity': '睡眠障碍、头痛、高血压脑病',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症'},
#  '青少年心理叛逆': {'disease_name': '青少年心理叛逆',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科',
#   'symptom': '烦躁不安',
#   'check': '心理咨询',
#   'infectivity': '心理障碍、病态人格、偏执性精神障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '社交恐惧症、心理障碍'},
#  '躁狂抑郁症': {'disease_name': '躁狂抑郁症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '抑郁、烦躁不安、情绪低落',
#   'check': None,
#   'infectivity': None,
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '精神分裂症、酒精中毒性精神障碍、神经衰弱'},
#  '躯体形式障碍': {'disease_name': '躯体形式障碍',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科,神经内科',
#   'symptom': '头痛、焦虑、便秘、抑郁、心悸、头晕、食欲缺乏',
#   'check': '心理咨询',
#   'infectivity': '妄想狂',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '精神分裂症、焦虑症、抑郁症、恐惧症'},
#  '神经性厌食症': {'disease_name': '神经性厌食症',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,神经内科,特色医疗科',
#   'symptom': '闭经、阳痿、消瘦、食欲减退、抑郁',
#   'check': '头部MRI、头部CT、心电图、脑电图(EEG)、X线平片',
#   'infectivity': '便秘、失眠、低血压、贫血、脱水、胃炎、头晕',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '精神分裂症、躯体化障碍、抑郁症、生理性厌食'},
#  '儿童强迫症': {'disease_name': '儿童强迫症',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,小儿精神科',
#   'symptom': '强迫行为、强迫观念',
#   'check': '血常规、心电图',
#   'infectivity': '强迫性动作、强迫性思维',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '强迫性障碍、强迫型人格障碍'},
#  '癫病': {'disease_name': '癫病',
#   'pathogenic_site': '全身',
#   'department': '中医内科',
#   'symptom': '肌肉萎缩、疲劳、瘫痪、无力、胸肌萎缩、大腿肌肉萎缩、手内肌萎缩、面肌萎缩、肩带肌、上肢和胸背部诸肌的肌无力和肌萎缩',
#   'check': '血常规、尿液检测、脑脊液检测',
#   'infectivity': '肌无力危象',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '痹证'},
#  '青春期厌食症': {'disease_name': '青春期厌食症',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,消化内科,神经内科',
#   'symptom': '身体瘦弱、皮肤干燥、月经过少、神经性厌食、体重减轻、拒食',
#   'check': '血常规、尿液检测、心电图、粪便检测、血清电解质检测、超声心动图',
#   'infectivity': '营养不良、心脏衰竭、感染性疾病',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '继发闭经、进食障碍'},
#  '精神发育迟滞': {'disease_name': '精神发育迟滞',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科,中医内科,神经内科',
#   'symptom': '智力发育迟缓、言语功能的部分丧失',
#   'check': '头部CT、脑电图(EEG)、染色体检测、神经系统检查、血液生化检测',
#   'infectivity': '人格障碍、智力低下',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '混合性特定性发育障碍、小儿多动症、发育迟缓、儿童孤独症、儿童精神分裂症'},
#  '伪聋': {'disease_name': '伪聋',
#   'pathogenic_site': '头颈部',
#   'department': '心理咨询科,耳鼻喉科',
#   'symptom': '耳聋、听力减退、听力下降',
#   'check': '听力检查',
#   'infectivity': '突发性耳聋',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '突发性耳聋'},
#  '儿童社交恐惧症': {'disease_name': '儿童社交恐惧症',
#   'pathogenic_site': '全身',
#   'department': '心理咨询科,小儿精神科,小儿神经内科',
#   'symptom': '紧张、场所恐惧',
#   'check': '心理咨询',
#   'infectivity': '疑病症、儿童分离性焦虑障碍',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '有遗传因素',
#   'susceptible_crowd': '焦虑症、疑病症、儿童强迫症、颞叶癫痫'},
#  '旅途精神病': {'disease_name': '旅途精神病',
#   'pathogenic_site': '全身',
#   'department': '精神病科,心理咨询科',
#   'symptom': '被害妄想、痴笑、幻听、幻味、疲劳、意识障碍、忧郁',
#   'check': '脑电图(EEG)',
#   'infectivity': None,
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '精神分裂症、情感障碍'},
#  '缢死': {'disease_name': '缢死',
#   'pathogenic_site': '全身',
#   'department': '急诊科,心血管内科',
#   'symptom': '运动性猝死、呼吸困难、心肌细胞的浊肿、猝死、血压下降、瞳孔扩大、心脏骤停、光反应消失、性交猝死、血压为零、噎食性猝死、心肺复苏术',
#   'check': '心电图、脑电图(EEG)',
#   'infectivity': '呼吸停止、呼吸心跳骤停',
#   'heredity': '该病不具有传染性',
#   'confusable_disease': '不遗传',
#   'susceptible_crowd': '低血糖症、肺栓塞、心脏病'}}

# %%
with open('psychological-counseling.json', 'w', encoding='utf-8') as f:
    json.dump(json_dic, f, ensure_ascii=False)
